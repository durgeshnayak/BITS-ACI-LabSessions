# %% [markdown]
# Stochastic Hill Climbing

# %%
import numpy as np
import random;

#The PEAS
#Time, Speed, Fuel, Distance
#Init_solution = [10, 100, 25, 10];
#Init_solution = [2,10,5,100]
#Init_solution=None
#Init_solution = [0, 0, 0, 0];


Iterations = 0
max_itr=10000
Final_solution = None

#Contains an objective vector of attributes to be optimized and the cost associated with the objectives
class Solu_space:
    def __init__(self):
        self.obj_vector = None
        self.cost = None
        
            
    def setObj_vector(self, val):
        self.obj_vector = val
            
    def setCost(self, cost):
        self.cost = cost
            
    def getAttr(self):
        return {'Time, Speed, Fuel, Distance': self.obj_vector, 'Cost': self.cost }
    #Time,speed,fuel,distance



# Function for calculating the cost - The evaluation function
def calc_cost(objVector):
    #print("Inside calc cost")
    #print(objVector)
    #objVector=objVector
    cost = round((objVector[0]   + objVector[1]  + objVector[2] - objVector[3]),2)
   # cost = objVector[0]   + objVector[1]  + (objVector[2]/objVector[3])
    #print("Cost"+str(cost))
    return abs(cost)
 
# Function to generate new solution in the neighborhood - Random
def gen_new_solution():
    distance_step=0
    speed_step=random.randint(10,100)
    time_step=round((random.randint(1,100))/60,2)
    #distance_step=random.randint(1,500)
    try:
        distance_step=random.randint(1,round(speed_step*time_step,2))
    except:
        pass
    fuel_step=random.randint(1,25)
                 #Time, Speed, Fuel, Distance
    objVector=[time_step,speed_step,fuel_step,distance_step]
    #print("new solution: "+str(objVector))
    return objVector

def Hill_Climb(objVector):
    #print("Inside Hill_Climb(objVector)")
    #print (objVector)
    soln_space = Solu_space()
    soln_space.setObj_vector(objVector)
    oldCost = calc_cost(objVector);
    soln_space.setCost(oldCost)
    
    #print("old objvector")
    #print(soln_space.obj_vector)
    #print("Old cost")
    #print(soln_space.cost)
    newobjVector = gen_new_solution()
    #print("new object vector")
    #print(newobjVector)
    newcost= calc_cost(newobjVector)
    #print("new cost")
    #print(newcost)
    
    if(newcost < oldCost):
        soln_space.setObj_vector(newobjVector)
        soln_space.setCost(newcost)
        #print(soln_space.obj_vector)
        #print(soln_space.cost)
        print(str(soln_space.getAttr()))
        return soln_space.obj_vector
    print(str(soln_space.getAttr()))
    return soln_space.obj_vector



def stopit():
    globals()
    cost=calc_cost(Final_solution)
    if cost == 0:
        return True
    if Iterations == max_itr:
        return True
    else: 
        return False
    
Init_soln=[random.randint(1,10),random.randint(1,100),random.randint(1,25),random.randint(1,500)]
Final_solution= Hill_Climb(Init_soln)
print(Final_solution)
while not stopit():
    solution=Final_solution
    Final_solution=Hill_Climb(solution)
    #print("Solution")
    #print("Time,Speed,Fuel,Distance Covered")
    #print(solution)
    #print(str(Final_solution[0])+ "  Hrs  " +str(Final_solution[1])+ "  Km/Hr  " + str(Final_solution[2]) + " Litres " + str(Final_solution[3]) + " Kms")
    #print("Cost" + str(calc_cost(Final_solution)))
    
    #print(calc_cost(Final_solution))
    print("Iteration no: "+str(Iterations))
    Iterations+=1
print("Solution")    
print(str(Final_solution[0])+ "  Hrs  " +str(Final_solution[1])+ "  Km/Hr  " + str(Final_solution[2]) + " Litres " + str(Final_solution[3]) + " Kms")
print("Cost" + str(calc_cost(Final_solution)))
# Out:
# {'Time, Speed, Fuel, Distance': [1.6, 71, 10, 0], 'Cost': 82.6}
# [1.6, 71, 10, 0]
# {'Time, Speed, Fuel, Distance': [1.6, 71, 10, 0], 'Cost': 82.6}
# Iteration no: 0
# {'Time, Speed, Fuel, Distance': [0.83, 61, 9, 0], 'Cost': 70.83}
# Iteration no: 1
# {'Time, Speed, Fuel, Distance': [1.08, 52, 1, 0], 'Cost': 54.08}
# Iteration no: 2
# {'Time, Speed, Fuel, Distance': [1.08, 52, 1, 0], 'Cost': 54.08}
# Iteration no: 3
# {'Time, Speed, Fuel, Distance': [0.07, 18, 25, 0], 'Cost': 43.07}
# Iteration no: 4
# {'Time, Speed, Fuel, Distance': [0.07, 18, 25, 0], 'Cost': 43.07}
# Iteration no: 5
# {'Time, Speed, Fuel, Distance': [0.07, 18, 25, 0], 'Cost': 43.07}
# Iteration no: 6
# {'Time, Speed, Fuel, Distance': [0.07, 18, 25, 0], 'Cost': 43.07}
# Iteration no: 7
# {'Time, Speed, Fuel, Distance': [0.07, 18, 25, 0], 'Cost': 43.07}
# Iteration no: 8
# {'Time, Speed, Fuel, Distance': [0.55, 36, 4, 0], 'Cost': 40.55}
# Iteration no: 9
# {'Time, Speed, Fuel, Distance': [0.48, 33, 1, 0], 'Cost': 34.48}
# Iteration no: 10
# {'Time, Speed, Fuel, Distance': [0.43, 19, 4, 0], 'Cost': 23.43}
# Iteration no: 11
# {'Time, Speed, Fuel, Distance': [0.43, 19, 4, 0], 'Cost': 23.43}
# Iteration no: 12
# {'Time, Speed, Fuel, Distance': [0.43, 19, 4, 0], 'Cost': 23.43}
# Iteration no: 13
# {'Time, Speed, Fuel, Distance': [0.43, 19, 4, 0], 'Cost': 23.43}
# Iteration no: 14
# {'Time, Speed, Fuel, Distance': [0.43, 19, 4, 0], 'Cost': 23.43}
# Iteration no: 15
# {'Time, Speed, Fuel, Distance': [0.43, 19, 4, 0], 'Cost': 23.43}
# Iteration no: 16
# {'Time, Speed, Fuel, Distance': [0.65, 20, 12, 12], 'Cost': 20.65}
# Iteration no: 17
# {'Time, Speed, Fuel, Distance': [0.65, 20, 12, 12], 'Cost': 20.65}
# Iteration no: 18
# {'Time, Speed, Fuel, Distance': [0.65, 20, 12, 12], 'Cost': 20.65}
# Iteration no: 19
# {'Time, Speed, Fuel, Distance': [0.65, 20, 12, 12], 'Cost': 20.65}
# Iteration no: 20
# {'Time, Speed, Fuel, Distance': [0.65, 20, 12, 12], 'Cost': 20.65}
# Iteration no: 21
# {'Time, Speed, Fuel, Distance': [0.65, 20, 12, 12], 'Cost': 20.65}
# Iteration no: 22
# {'Time, Speed, Fuel, Distance': [0.65, 20, 12, 12], 'Cost': 20.65}
# Iteration no: 23
# {'Time, Speed, Fuel, Distance': [0.65, 20, 12, 12], 'Cost': 20.65}
# Iteration no: 24
# {'Time, Speed, Fuel, Distance': [0.65, 20, 12, 12], 'Cost': 20.65}
# Iteration no: 25
# {'Time, Speed, Fuel, Distance': [0.65, 20, 12, 12], 'Cost': 20.65}
# Iteration no: 26
# {'Time, Speed, Fuel, Distance': [0.65, 20, 12, 12], 'Cost': 20.65}
# Iteration no: 27
# {'Time, Speed, Fuel, Distance': [0.65, 20, 12, 12], 'Cost': 20.65}
# Iteration no: 28
# {'Time, Speed, Fuel, Distance': [0.65, 20, 12, 12], 'Cost': 20.65}
# Iteration no: 29
# {'Time, Speed, Fuel, Distance': [0.65, 20, 12, 12], 'Cost': 20.65}
# Iteration no: 30
# {'Time, Speed, Fuel, Distance': [0.65, 20, 12, 12], 'Cost': 20.65}
# Iteration no: 31
# {'Time, Speed, Fuel, Distance': [0.65, 20, 12, 12], 'Cost': 20.65}
# Iteration no: 32
# {'Time, Speed, Fuel, Distance': [0.65, 20, 12, 12], 'Cost': 20.65}
# Iteration no: 33
# {'Time, Speed, Fuel, Distance': [0.65, 20, 12, 12], 'Cost': 20.65}
# Iteration no: 34
# {'Time, Speed, Fuel, Distance': [0.65, 20, 12, 12], 'Cost': 20.65}
# Iteration no: 35
# {'Time, Speed, Fuel, Distance': [0.65, 20, 12, 12], 'Cost': 20.65}
# Iteration no: 36
# {'Time, Speed, Fuel, Distance': [0.65, 20, 12, 12], 'Cost': 20.65}
# Iteration no: 37
# {'Time, Speed, Fuel, Distance': [0.65, 20, 12, 12], 'Cost': 20.65}
# Iteration no: 38
# {'Time, Speed, Fuel, Distance': [0.65, 20, 12, 12], 'Cost': 20.65}
# Iteration no: 39
# {'Time, Speed, Fuel, Distance': [0.65, 20, 12, 12], 'Cost': 20.65}
# Iteration no: 40
# {'Time, Speed, Fuel, Distance': [0.65, 20, 12, 12], 'Cost': 20.65}
# Iteration no: 41
# {'Time, Speed, Fuel, Distance': [0.65, 20, 12, 12], 'Cost': 20.65}
# Iteration no: 42
# {'Time, Speed, Fuel, Distance': [0.65, 20, 12, 12], 'Cost': 20.65}
# Iteration no: 43
# {'Time, Speed, Fuel, Distance': [0.65, 20, 12, 12], 'Cost': 20.65}
# Iteration no: 44
# {'Time, Speed, Fuel, Distance': [0.65, 20, 12, 12], 'Cost': 20.65}
# Iteration no: 45
# {'Time, Speed, Fuel, Distance': [0.65, 20, 12, 12], 'Cost': 20.65}
# Iteration no: 46
# {'Time, Speed, Fuel, Distance': [0.65, 20, 12, 12], 'Cost': 20.65}
# Iteration no: 47
# {'Time, Speed, Fuel, Distance': [0.65, 20, 12, 12], 'Cost': 20.65}
# Iteration no: 48
# {'Time, Speed, Fuel, Distance': [0.65, 20, 12, 12], 'Cost': 20.65}
# Iteration no: 49
# {'Time, Speed, Fuel, Distance': [0.65, 20, 12, 12], 'Cost': 20.65}
# Iteration no: 50
# {'Time, Speed, Fuel, Distance': [0.65, 20, 12, 12], 'Cost': 20.65}
# Iteration no: 51
# {'Time, Speed, Fuel, Distance': [0.65, 20, 12, 12], 'Cost': 20.65}
# Iteration no: 52
# {'Time, Speed, Fuel, Distance': [0.65, 20, 12, 12], 'Cost': 20.65}
# Iteration no: 53
# {'Time, Speed, Fuel, Distance': [0.65, 20, 12, 12], 'Cost': 20.65}
# Iteration no: 54
# {'Time, Speed, Fuel, Distance': [0.65, 20, 12, 12], 'Cost': 20.65}
# Iteration no: 55
# {'Time, Speed, Fuel, Distance': [0.65, 20, 12, 12], 'Cost': 20.65}
# Iteration no: 56
# {'Time, Speed, Fuel, Distance': [0.65, 20, 12, 12], 'Cost': 20.65}
# Iteration no: 57
# {'Time, Speed, Fuel, Distance': [0.65, 20, 12, 12], 'Cost': 20.65}
# Iteration no: 58
# {'Time, Speed, Fuel, Distance': [0.65, 20, 12, 12], 'Cost': 20.65}
# Iteration no: 59
# {'Time, Speed, Fuel, Distance': [0.65, 20, 12, 12], 'Cost': 20.65}
# Iteration no: 60
# {'Time, Speed, Fuel, Distance': [0.65, 20, 12, 12], 'Cost': 20.65}
# Iteration no: 61
# {'Time, Speed, Fuel, Distance': [0.65, 20, 12, 12], 'Cost': 20.65}
# Iteration no: 62
# {'Time, Speed, Fuel, Distance': [0.65, 20, 12, 12], 'Cost': 20.65}
# Iteration no: 63
# {'Time, Speed, Fuel, Distance': [0.65, 20, 12, 12], 'Cost': 20.65}
# Iteration no: 64
# {'Time, Speed, Fuel, Distance': [0.65, 20, 12, 12], 'Cost': 20.65}
# Iteration no: 65
# {'Time, Speed, Fuel, Distance': [0.55, 10, 5, 0], 'Cost': 15.55}
# Iteration no: 66
# {'Time, Speed, Fuel, Distance': [0.55, 10, 5, 0], 'Cost': 15.55}
# Iteration no: 67
# {'Time, Speed, Fuel, Distance': [0.55, 10, 5, 0], 'Cost': 15.55}
# Iteration no: 68
# {'Time, Speed, Fuel, Distance': [0.55, 10, 5, 0], 'Cost': 15.55}
# Iteration no: 69
# {'Time, Speed, Fuel, Distance': [0.55, 10, 5, 0], 'Cost': 15.55}
# Iteration no: 70
# {'Time, Speed, Fuel, Distance': [0.55, 10, 5, 0], 'Cost': 15.55}
# Iteration no: 71
# {'Time, Speed, Fuel, Distance': [0.55, 10, 5, 0], 'Cost': 15.55}
# Iteration no: 72
# {'Time, Speed, Fuel, Distance': [0.55, 10, 5, 0], 'Cost': 15.55}
# Iteration no: 73
# {'Time, Speed, Fuel, Distance': [0.55, 10, 5, 0], 'Cost': 15.55}
# Iteration no: 74
# {'Time, Speed, Fuel, Distance': [0.55, 10, 5, 0], 'Cost': 15.55}
# Iteration no: 75
# {'Time, Speed, Fuel, Distance': [0.55, 10, 5, 0], 'Cost': 15.55}
# Iteration no: 76
# {'Time, Speed, Fuel, Distance': [0.55, 10, 5, 0], 'Cost': 15.55}
# Iteration no: 77
# {'Time, Speed, Fuel, Distance': [0.55, 10, 5, 0], 'Cost': 15.55}
# Iteration no: 78
# {'Time, Speed, Fuel, Distance': [0.55, 10, 5, 0], 'Cost': 15.55}
# Iteration no: 79
# {'Time, Speed, Fuel, Distance': [0.55, 10, 5, 0], 'Cost': 15.55}
# Iteration no: 80
# {'Time, Speed, Fuel, Distance': [0.55, 10, 5, 0], 'Cost': 15.55}
# Iteration no: 81
# {'Time, Speed, Fuel, Distance': [0.55, 10, 5, 0], 'Cost': 15.55}
# Iteration no: 82
# {'Time, Speed, Fuel, Distance': [0.55, 10, 5, 0], 'Cost': 15.55}
# Iteration no: 83
# {'Time, Speed, Fuel, Distance': [0.55, 10, 5, 0], 'Cost': 15.55}
# Iteration no: 84
# {'Time, Speed, Fuel, Distance': [0.55, 10, 5, 0], 'Cost': 15.55}
# Iteration no: 85
# {'Time, Speed, Fuel, Distance': [0.55, 10, 5, 0], 'Cost': 15.55}
# Iteration no: 86
# {'Time, Speed, Fuel, Distance': [0.55, 10, 5, 0], 'Cost': 15.55}
# Iteration no: 87
# {'Time, Speed, Fuel, Distance': [0.55, 10, 5, 0], 'Cost': 15.55}
# Iteration no: 88
# {'Time, Speed, Fuel, Distance': [0.55, 10, 5, 0], 'Cost': 15.55}
# Iteration no: 89
# {'Time, Speed, Fuel, Distance': [0.55, 10, 5, 0], 'Cost': 15.55}
# Iteration no: 90
# {'Time, Speed, Fuel, Distance': [0.55, 10, 5, 0], 'Cost': 15.55}
# Iteration no: 91
# {'Time, Speed, Fuel, Distance': [0.55, 10, 5, 0], 'Cost': 15.55}
# Iteration no: 92
# {'Time, Speed, Fuel, Distance': [0.55, 10, 5, 0], 'Cost': 15.55}
# Iteration no: 93
# {'Time, Speed, Fuel, Distance': [0.55, 10, 5, 0], 'Cost': 15.55}
# Iteration no: 94
# {'Time, Speed, Fuel, Distance': [0.55, 10, 5, 0], 'Cost': 15.55}
# Iteration no: 95
# {'Time, Speed, Fuel, Distance': [0.55, 10, 5, 0], 'Cost': 15.55}
# Iteration no: 96
# {'Time, Speed, Fuel, Distance': [0.55, 10, 5, 0], 'Cost': 15.55}
# Iteration no: 97
# {'Time, Speed, Fuel, Distance': [0.55, 10, 5, 0], 'Cost': 15.55}
# Iteration no: 98
# {'Time, Speed, Fuel, Distance': [0.55, 10, 5, 0], 'Cost': 15.55}
# Iteration no: 99
# {'Time, Speed, Fuel, Distance': [0.55, 10, 5, 0], 'Cost': 15.55}
# Iteration no: 100
# {'Time, Speed, Fuel, Distance': [0.55, 10, 5, 0], 'Cost': 15.55}
# Iteration no: 101
# {'Time, Speed, Fuel, Distance': [0.55, 10, 5, 0], 'Cost': 15.55}
# Iteration no: 102
# {'Time, Speed, Fuel, Distance': [0.55, 10, 5, 0], 'Cost': 15.55}
# Iteration no: 103
# {'Time, Speed, Fuel, Distance': [0.55, 10, 5, 0], 'Cost': 15.55}
# Iteration no: 104
# {'Time, Speed, Fuel, Distance': [0.55, 10, 5, 0], 'Cost': 15.55}
# Iteration no: 105
# {'Time, Speed, Fuel, Distance': [0.55, 10, 5, 0], 'Cost': 15.55}
# Iteration no: 106
# {'Time, Speed, Fuel, Distance': [0.55, 10, 5, 0], 'Cost': 15.55}
# Iteration no: 107
# {'Time, Speed, Fuel, Distance': [0.55, 10, 5, 0], 'Cost': 15.55}
# Iteration no: 108
# {'Time, Speed, Fuel, Distance': [0.55, 10, 5, 0], 'Cost': 15.55}
# Iteration no: 109
# {'Time, Speed, Fuel, Distance': [0.55, 10, 5, 0], 'Cost': 15.55}
# Iteration no: 110
# {'Time, Speed, Fuel, Distance': [0.55, 10, 5, 0], 'Cost': 15.55}
# Iteration no: 111
# {'Time, Speed, Fuel, Distance': [0.55, 10, 5, 0], 'Cost': 15.55}
# Iteration no: 112
# {'Time, Speed, Fuel, Distance': [0.55, 10, 5, 0], 'Cost': 15.55}
# Iteration no: 113
# {'Time, Speed, Fuel, Distance': [0.55, 10, 5, 0], 'Cost': 15.55}
# Iteration no: 114
# {'Time, Speed, Fuel, Distance': [0.55, 10, 5, 0], 'Cost': 15.55}
# Iteration no: 115
# {'Time, Speed, Fuel, Distance': [0.55, 10, 5, 0], 'Cost': 15.55}
# Iteration no: 116
# {'Time, Speed, Fuel, Distance': [0.55, 10, 5, 0], 'Cost': 15.55}
# Iteration no: 117
# {'Time, Speed, Fuel, Distance': [0.55, 10, 5, 0], 'Cost': 15.55}
# Iteration no: 118
# {'Time, Speed, Fuel, Distance': [0.55, 10, 5, 0], 'Cost': 15.55}
# Iteration no: 119
# {'Time, Speed, Fuel, Distance': [0.55, 10, 5, 0], 'Cost': 15.55}
# Iteration no: 120
# {'Time, Speed, Fuel, Distance': [0.55, 10, 5, 0], 'Cost': 15.55}
# Iteration no: 121
# {'Time, Speed, Fuel, Distance': [0.55, 10, 5, 0], 'Cost': 15.55}
# Iteration no: 122
# {'Time, Speed, Fuel, Distance': [0.55, 10, 5, 0], 'Cost': 15.55}
# Iteration no: 123
# {'Time, Speed, Fuel, Distance': [0.55, 10, 5, 0], 'Cost': 15.55}
# Iteration no: 124
# {'Time, Speed, Fuel, Distance': [0.55, 10, 5, 0], 'Cost': 15.55}
# Iteration no: 125
# {'Time, Speed, Fuel, Distance': [0.55, 10, 5, 0], 'Cost': 15.55}
# Iteration no: 126
# {'Time, Speed, Fuel, Distance': [0.55, 10, 5, 0], 'Cost': 15.55}
# Iteration no: 127
# {'Time, Speed, Fuel, Distance': [0.55, 10, 5, 0], 'Cost': 15.55}
# Iteration no: 128
# {'Time, Speed, Fuel, Distance': [0.55, 10, 5, 0], 'Cost': 15.55}
# Iteration no: 129
# {'Time, Speed, Fuel, Distance': [0.55, 10, 5, 0], 'Cost': 15.55}
# Iteration no: 130
# {'Time, Speed, Fuel, Distance': [0.55, 10, 5, 0], 'Cost': 15.55}
# Iteration no: 131
# {'Time, Speed, Fuel, Distance': [0.55, 10, 5, 0], 'Cost': 15.55}
# Iteration no: 132
# {'Time, Speed, Fuel, Distance': [0.55, 10, 5, 0], 'Cost': 15.55}
# Iteration no: 133
# {'Time, Speed, Fuel, Distance': [0.55, 10, 5, 0], 'Cost': 15.55}
# Iteration no: 134
# {'Time, Speed, Fuel, Distance': [0.55, 10, 5, 0], 'Cost': 15.55}
# Iteration no: 135
# {'Time, Speed, Fuel, Distance': [0.55, 10, 5, 0], 'Cost': 15.55}
# Iteration no: 136
# {'Time, Speed, Fuel, Distance': [0.55, 10, 5, 0], 'Cost': 15.55}
# Iteration no: 137
# {'Time, Speed, Fuel, Distance': [0.55, 10, 5, 0], 'Cost': 15.55}
# Iteration no: 138
# {'Time, Speed, Fuel, Distance': [0.55, 10, 5, 0], 'Cost': 15.55}
# Iteration no: 139
# {'Time, Speed, Fuel, Distance': [0.55, 10, 5, 0], 'Cost': 15.55}
# Iteration no: 140
# {'Time, Speed, Fuel, Distance': [0.55, 10, 5, 0], 'Cost': 15.55}
# Iteration no: 141
# {'Time, Speed, Fuel, Distance': [0.55, 10, 5, 0], 'Cost': 15.55}
# Iteration no: 142
# {'Time, Speed, Fuel, Distance': [0.55, 10, 5, 0], 'Cost': 15.55}
# Iteration no: 143
# {'Time, Speed, Fuel, Distance': [0.55, 10, 5, 0], 'Cost': 15.55}
# Iteration no: 144
# {'Time, Speed, Fuel, Distance': [0.55, 10, 5, 0], 'Cost': 15.55}
# Iteration no: 145
# {'Time, Speed, Fuel, Distance': [0.55, 10, 5, 0], 'Cost': 15.55}
# Iteration no: 146
# {'Time, Speed, Fuel, Distance': [0.55, 10, 5, 0], 'Cost': 15.55}
# Iteration no: 147
# {'Time, Speed, Fuel, Distance': [0.55, 10, 5, 0], 'Cost': 15.55}
# Iteration no: 148
# {'Time, Speed, Fuel, Distance': [0.55, 10, 5, 0], 'Cost': 15.55}
# Iteration no: 149
# {'Time, Speed, Fuel, Distance': [0.55, 10, 5, 0], 'Cost': 15.55}
# Iteration no: 150
# {'Time, Speed, Fuel, Distance': [0.55, 10, 5, 0], 'Cost': 15.55}
# Iteration no: 151
# {'Time, Speed, Fuel, Distance': [0.55, 10, 5, 0], 'Cost': 15.55}
# Iteration no: 152
# {'Time, Speed, Fuel, Distance': [0.55, 10, 5, 0], 'Cost': 15.55}
# Iteration no: 153
# {'Time, Speed, Fuel, Distance': [0.55, 10, 5, 0], 'Cost': 15.55}
# Iteration no: 154
# {'Time, Speed, Fuel, Distance': [0.55, 10, 5, 0], 'Cost': 15.55}
# Iteration no: 155
# {'Time, Speed, Fuel, Distance': [0.55, 10, 5, 0], 'Cost': 15.55}
# Iteration no: 156
# {'Time, Speed, Fuel, Distance': [0.55, 10, 5, 0], 'Cost': 15.55}
# Iteration no: 157
# {'Time, Speed, Fuel, Distance': [0.55, 10, 5, 0], 'Cost': 15.55}
# Iteration no: 158
# {'Time, Speed, Fuel, Distance': [0.55, 10, 5, 0], 'Cost': 15.55}
# Iteration no: 159
# {'Time, Speed, Fuel, Distance': [0.55, 10, 5, 0], 'Cost': 15.55}
# Iteration no: 160
# {'Time, Speed, Fuel, Distance': [0.55, 10, 5, 0], 'Cost': 15.55}
# Iteration no: 161
# {'Time, Speed, Fuel, Distance': [0.55, 10, 5, 0], 'Cost': 15.55}
# Iteration no: 162
# {'Time, Speed, Fuel, Distance': [0.55, 10, 5, 0], 'Cost': 15.55}
# Iteration no: 163
# {'Time, Speed, Fuel, Distance': [0.55, 10, 5, 0], 'Cost': 15.55}
# Iteration no: 164
# {'Time, Speed, Fuel, Distance': [0.55, 10, 5, 0], 'Cost': 15.55}
# Iteration no: 165
# {'Time, Speed, Fuel, Distance': [0.55, 10, 5, 0], 'Cost': 15.55}
# Iteration no: 166
# {'Time, Speed, Fuel, Distance': [1.2, 45, 9, 44], 'Cost': 11.2}
# Iteration no: 167
# {'Time, Speed, Fuel, Distance': [1.2, 45, 9, 44], 'Cost': 11.2}
# Iteration no: 168
# {'Time, Speed, Fuel, Distance': [1.2, 45, 9, 44], 'Cost': 11.2}
# Iteration no: 169
# {'Time, Speed, Fuel, Distance': [1.2, 45, 9, 44], 'Cost': 11.2}
# Iteration no: 170
# {'Time, Speed, Fuel, Distance': [1.2, 45, 9, 44], 'Cost': 11.2}
# Iteration no: 171
# {'Time, Speed, Fuel, Distance': [1.2, 45, 9, 44], 'Cost': 11.2}
# Iteration no: 172
# {'Time, Speed, Fuel, Distance': [1.2, 45, 9, 44], 'Cost': 11.2}
# Iteration no: 173
# {'Time, Speed, Fuel, Distance': [1.2, 45, 9, 44], 'Cost': 11.2}
# Iteration no: 174
# {'Time, Speed, Fuel, Distance': [1.2, 45, 9, 44], 'Cost': 11.2}
# Iteration no: 175
# {'Time, Speed, Fuel, Distance': [1.2, 45, 9, 44], 'Cost': 11.2}
# Iteration no: 176
# {'Time, Speed, Fuel, Distance': [1.2, 45, 9, 44], 'Cost': 11.2}
# Iteration no: 177
# {'Time, Speed, Fuel, Distance': [1.2, 45, 9, 44], 'Cost': 11.2}
# Iteration no: 178
# {'Time, Speed, Fuel, Distance': [1.2, 45, 9, 44], 'Cost': 11.2}
# Iteration no: 179
# {'Time, Speed, Fuel, Distance': [1.2, 45, 9, 44], 'Cost': 11.2}
# Iteration no: 180
# {'Time, Speed, Fuel, Distance': [1.2, 45, 9, 44], 'Cost': 11.2}
# Iteration no: 181
# {'Time, Speed, Fuel, Distance': [1.2, 45, 9, 44], 'Cost': 11.2}
# Iteration no: 182
# {'Time, Speed, Fuel, Distance': [1.2, 45, 9, 44], 'Cost': 11.2}
# Iteration no: 183
# {'Time, Speed, Fuel, Distance': [1.2, 45, 9, 44], 'Cost': 11.2}
# Iteration no: 184
# {'Time, Speed, Fuel, Distance': [1.2, 45, 9, 44], 'Cost': 11.2}
# Iteration no: 185
# {'Time, Speed, Fuel, Distance': [1.2, 45, 9, 44], 'Cost': 11.2}
# Iteration no: 186
# {'Time, Speed, Fuel, Distance': [1.2, 45, 9, 44], 'Cost': 11.2}
# Iteration no: 187
# {'Time, Speed, Fuel, Distance': [1.2, 45, 9, 44], 'Cost': 11.2}
# Iteration no: 188
# {'Time, Speed, Fuel, Distance': [1.2, 45, 9, 44], 'Cost': 11.2}
# Iteration no: 189
# {'Time, Speed, Fuel, Distance': [1.2, 45, 9, 44], 'Cost': 11.2}
# Iteration no: 190
# {'Time, Speed, Fuel, Distance': [1.2, 45, 9, 44], 'Cost': 11.2}
# Iteration no: 191
# {'Time, Speed, Fuel, Distance': [1.2, 45, 9, 44], 'Cost': 11.2}
# Iteration no: 192
# {'Time, Speed, Fuel, Distance': [1.2, 45, 9, 44], 'Cost': 11.2}
# Iteration no: 193
# {'Time, Speed, Fuel, Distance': [1.2, 45, 9, 44], 'Cost': 11.2}
# Iteration no: 194
# {'Time, Speed, Fuel, Distance': [1.2, 45, 9, 44], 'Cost': 11.2}
# Iteration no: 195
# {'Time, Speed, Fuel, Distance': [1.2, 45, 9, 44], 'Cost': 11.2}
# Iteration no: 196
# {'Time, Speed, Fuel, Distance': [1.2, 45, 9, 44], 'Cost': 11.2}
# Iteration no: 197
# {'Time, Speed, Fuel, Distance': [1.2, 45, 9, 44], 'Cost': 11.2}
# Iteration no: 198
# {'Time, Speed, Fuel, Distance': [1.2, 45, 9, 44], 'Cost': 11.2}
# Iteration no: 199
# {'Time, Speed, Fuel, Distance': [1.2, 45, 9, 44], 'Cost': 11.2}
# Iteration no: 200
# {'Time, Speed, Fuel, Distance': [1.2, 45, 9, 44], 'Cost': 11.2}
# Iteration no: 201
# {'Time, Speed, Fuel, Distance': [1.2, 45, 9, 44], 'Cost': 11.2}
# Iteration no: 202
# {'Time, Speed, Fuel, Distance': [1.2, 45, 9, 44], 'Cost': 11.2}
# Iteration no: 203
# {'Time, Speed, Fuel, Distance': [1.2, 45, 9, 44], 'Cost': 11.2}
# Iteration no: 204
# {'Time, Speed, Fuel, Distance': [1.2, 45, 9, 44], 'Cost': 11.2}
# Iteration no: 205
# {'Time, Speed, Fuel, Distance': [1.2, 45, 9, 44], 'Cost': 11.2}
# Iteration no: 206
# {'Time, Speed, Fuel, Distance': [1.2, 45, 9, 44], 'Cost': 11.2}
# Iteration no: 207
# {'Time, Speed, Fuel, Distance': [1.2, 45, 9, 44], 'Cost': 11.2}
# Iteration no: 208
# {'Time, Speed, Fuel, Distance': [1.2, 45, 9, 44], 'Cost': 11.2}
# Iteration no: 209
# {'Time, Speed, Fuel, Distance': [1.2, 45, 9, 44], 'Cost': 11.2}
# Iteration no: 210
# {'Time, Speed, Fuel, Distance': [1.2, 45, 9, 44], 'Cost': 11.2}
# Iteration no: 211
# {'Time, Speed, Fuel, Distance': [1.2, 45, 9, 44], 'Cost': 11.2}
# Iteration no: 212
# {'Time, Speed, Fuel, Distance': [1.2, 45, 9, 44], 'Cost': 11.2}
# Iteration no: 213
# {'Time, Speed, Fuel, Distance': [1.2, 45, 9, 44], 'Cost': 11.2}
# Iteration no: 214
# {'Time, Speed, Fuel, Distance': [1.2, 45, 9, 44], 'Cost': 11.2}
# Iteration no: 215
# {'Time, Speed, Fuel, Distance': [1.2, 45, 9, 44], 'Cost': 11.2}
# Iteration no: 216
# {'Time, Speed, Fuel, Distance': [1.2, 45, 9, 44], 'Cost': 11.2}
# Iteration no: 217
# {'Time, Speed, Fuel, Distance': [1.2, 45, 9, 44], 'Cost': 11.2}
# Iteration no: 218
# {'Time, Speed, Fuel, Distance': [1.2, 45, 9, 44], 'Cost': 11.2}
# Iteration no: 219
# {'Time, Speed, Fuel, Distance': [1.2, 45, 9, 44], 'Cost': 11.2}
# Iteration no: 220
# {'Time, Speed, Fuel, Distance': [1.2, 45, 9, 44], 'Cost': 11.2}
# Iteration no: 221
# {'Time, Speed, Fuel, Distance': [1.2, 45, 9, 44], 'Cost': 11.2}
# Iteration no: 222
# {'Time, Speed, Fuel, Distance': [1.2, 45, 9, 44], 'Cost': 11.2}
# Iteration no: 223
# {'Time, Speed, Fuel, Distance': [1.2, 45, 9, 44], 'Cost': 11.2}
# Iteration no: 224
# {'Time, Speed, Fuel, Distance': [1.2, 45, 9, 44], 'Cost': 11.2}
# Iteration no: 225
# {'Time, Speed, Fuel, Distance': [1.2, 45, 9, 44], 'Cost': 11.2}
# Iteration no: 226
# {'Time, Speed, Fuel, Distance': [1.2, 45, 9, 44], 'Cost': 11.2}
# Iteration no: 227
# {'Time, Speed, Fuel, Distance': [1.2, 45, 9, 44], 'Cost': 11.2}
# Iteration no: 228
# {'Time, Speed, Fuel, Distance': [1.2, 45, 9, 44], 'Cost': 11.2}
# Iteration no: 229
# {'Time, Speed, Fuel, Distance': [1.2, 45, 9, 44], 'Cost': 11.2}
# Iteration no: 230
# {'Time, Speed, Fuel, Distance': [1.2, 45, 9, 44], 'Cost': 11.2}
# Iteration no: 231
# {'Time, Speed, Fuel, Distance': [1.2, 45, 9, 44], 'Cost': 11.2}
# Iteration no: 232
# {'Time, Speed, Fuel, Distance': [1.2, 45, 9, 44], 'Cost': 11.2}
# Iteration no: 233
# {'Time, Speed, Fuel, Distance': [1.2, 45, 9, 44], 'Cost': 11.2}
# Iteration no: 234
# {'Time, Speed, Fuel, Distance': [1.2, 45, 9, 44], 'Cost': 11.2}
# Iteration no: 235
# {'Time, Speed, Fuel, Distance': [1.2, 45, 9, 44], 'Cost': 11.2}
# Iteration no: 236
# {'Time, Speed, Fuel, Distance': [1.2, 45, 9, 44], 'Cost': 11.2}
# Iteration no: 237
# {'Time, Speed, Fuel, Distance': [1.2, 45, 9, 44], 'Cost': 11.2}
# Iteration no: 238
# {'Time, Speed, Fuel, Distance': [1.2, 45, 9, 44], 'Cost': 11.2}
# Iteration no: 239
# {'Time, Speed, Fuel, Distance': [1.2, 45, 9, 44], 'Cost': 11.2}
# Iteration no: 240
# {'Time, Speed, Fuel, Distance': [1.2, 45, 9, 44], 'Cost': 11.2}
# Iteration no: 241
# {'Time, Speed, Fuel, Distance': [1.2, 45, 9, 44], 'Cost': 11.2}
# Iteration no: 242
# {'Time, Speed, Fuel, Distance': [1.2, 45, 9, 44], 'Cost': 11.2}
# Iteration no: 243
# {'Time, Speed, Fuel, Distance': [1.2, 45, 9, 44], 'Cost': 11.2}
# Iteration no: 244
# {'Time, Speed, Fuel, Distance': [1.2, 45, 9, 44], 'Cost': 11.2}
# Iteration no: 245
# {'Time, Speed, Fuel, Distance': [1.2, 45, 9, 44], 'Cost': 11.2}
# Iteration no: 246
# {'Time, Speed, Fuel, Distance': [1.2, 45, 9, 44], 'Cost': 11.2}
# Iteration no: 247
# {'Time, Speed, Fuel, Distance': [1.2, 45, 9, 44], 'Cost': 11.2}
# Iteration no: 248
# {'Time, Speed, Fuel, Distance': [1.2, 45, 9, 44], 'Cost': 11.2}
# Iteration no: 249
# {'Time, Speed, Fuel, Distance': [1.2, 45, 9, 44], 'Cost': 11.2}
# Iteration no: 250
# {'Time, Speed, Fuel, Distance': [1.2, 45, 9, 44], 'Cost': 11.2}
# Iteration no: 251
# {'Time, Speed, Fuel, Distance': [1.2, 45, 9, 44], 'Cost': 11.2}
# Iteration no: 252
# {'Time, Speed, Fuel, Distance': [1.2, 45, 9, 44], 'Cost': 11.2}
# Iteration no: 253
# {'Time, Speed, Fuel, Distance': [1.2, 45, 9, 44], 'Cost': 11.2}
# Iteration no: 254
# {'Time, Speed, Fuel, Distance': [1.2, 45, 9, 44], 'Cost': 11.2}
# Iteration no: 255
# {'Time, Speed, Fuel, Distance': [1.2, 45, 9, 44], 'Cost': 11.2}
# Iteration no: 256
# {'Time, Speed, Fuel, Distance': [1.2, 45, 9, 44], 'Cost': 11.2}
# Iteration no: 257
# {'Time, Speed, Fuel, Distance': [1.2, 45, 9, 44], 'Cost': 11.2}
# Iteration no: 258
# {'Time, Speed, Fuel, Distance': [1.2, 45, 9, 44], 'Cost': 11.2}
# Iteration no: 259
# {'Time, Speed, Fuel, Distance': [1.2, 45, 9, 44], 'Cost': 11.2}
# Iteration no: 260
# {'Time, Speed, Fuel, Distance': [1.2, 45, 9, 44], 'Cost': 11.2}
# Iteration no: 261
# {'Time, Speed, Fuel, Distance': [1.2, 45, 9, 44], 'Cost': 11.2}
# Iteration no: 262
# {'Time, Speed, Fuel, Distance': [1.2, 45, 9, 44], 'Cost': 11.2}
# Iteration no: 263
# {'Time, Speed, Fuel, Distance': [1.2, 45, 9, 44], 'Cost': 11.2}
# Iteration no: 264
# {'Time, Speed, Fuel, Distance': [1.2, 45, 9, 44], 'Cost': 11.2}
# Iteration no: 265
# {'Time, Speed, Fuel, Distance': [1.2, 45, 9, 44], 'Cost': 11.2}
# Iteration no: 266
# {'Time, Speed, Fuel, Distance': [1.2, 45, 9, 44], 'Cost': 11.2}
# Iteration no: 267
# {'Time, Speed, Fuel, Distance': [1.2, 45, 9, 44], 'Cost': 11.2}
# Iteration no: 268
# {'Time, Speed, Fuel, Distance': [1.2, 45, 9, 44], 'Cost': 11.2}
# Iteration no: 269
# {'Time, Speed, Fuel, Distance': [1.2, 45, 9, 44], 'Cost': 11.2}
# Iteration no: 270
# {'Time, Speed, Fuel, Distance': [1.2, 45, 9, 44], 'Cost': 11.2}
# Iteration no: 271
# {'Time, Speed, Fuel, Distance': [1.2, 45, 9, 44], 'Cost': 11.2}
# Iteration no: 272
# {'Time, Speed, Fuel, Distance': [1.2, 45, 9, 44], 'Cost': 11.2}
# Iteration no: 273
# {'Time, Speed, Fuel, Distance': [1.2, 45, 9, 44], 'Cost': 11.2}
# Iteration no: 274
# {'Time, Speed, Fuel, Distance': [1.2, 45, 9, 44], 'Cost': 11.2}
# Iteration no: 275
# {'Time, Speed, Fuel, Distance': [1.2, 45, 9, 44], 'Cost': 11.2}
# Iteration no: 276
# {'Time, Speed, Fuel, Distance': [1.2, 45, 9, 44], 'Cost': 11.2}
# Iteration no: 277
# {'Time, Speed, Fuel, Distance': [1.2, 45, 9, 44], 'Cost': 11.2}
# Iteration no: 278
# {'Time, Speed, Fuel, Distance': [1.2, 45, 9, 44], 'Cost': 11.2}
# Iteration no: 279
# {'Time, Speed, Fuel, Distance': [1.2, 45, 9, 44], 'Cost': 11.2}
# Iteration no: 280
# {'Time, Speed, Fuel, Distance': [1.2, 45, 9, 44], 'Cost': 11.2}
# Iteration no: 281
# {'Time, Speed, Fuel, Distance': [1.2, 45, 9, 44], 'Cost': 11.2}
# Iteration no: 282
# {'Time, Speed, Fuel, Distance': [1.2, 45, 9, 44], 'Cost': 11.2}
# Iteration no: 283
# {'Time, Speed, Fuel, Distance': [1.2, 45, 9, 44], 'Cost': 11.2}
# Iteration no: 284
# {'Time, Speed, Fuel, Distance': [1.2, 45, 9, 44], 'Cost': 11.2}
# Iteration no: 285
# {'Time, Speed, Fuel, Distance': [1.2, 45, 9, 44], 'Cost': 11.2}
# Iteration no: 286
# {'Time, Speed, Fuel, Distance': [1.2, 45, 9, 44], 'Cost': 11.2}
# Iteration no: 287
# {'Time, Speed, Fuel, Distance': [1.2, 45, 9, 44], 'Cost': 11.2}
# Iteration no: 288
# {'Time, Speed, Fuel, Distance': [1.2, 45, 9, 44], 'Cost': 11.2}
# Iteration no: 289
# {'Time, Speed, Fuel, Distance': [1.2, 45, 9, 44], 'Cost': 11.2}
# Iteration no: 290
# {'Time, Speed, Fuel, Distance': [1.2, 45, 9, 44], 'Cost': 11.2}
# Iteration no: 291
# {'Time, Speed, Fuel, Distance': [1.2, 45, 9, 44], 'Cost': 11.2}
# Iteration no: 292
# {'Time, Speed, Fuel, Distance': [1.2, 45, 9, 44], 'Cost': 11.2}
# Iteration no: 293
# {'Time, Speed, Fuel, Distance': [1.2, 45, 9, 44], 'Cost': 11.2}
# Iteration no: 294
# {'Time, Speed, Fuel, Distance': [1.2, 45, 9, 44], 'Cost': 11.2}
# Iteration no: 295
# {'Time, Speed, Fuel, Distance': [1.2, 45, 9, 44], 'Cost': 11.2}
# Iteration no: 296
# {'Time, Speed, Fuel, Distance': [1.2, 45, 9, 44], 'Cost': 11.2}
# Iteration no: 297
# {'Time, Speed, Fuel, Distance': [1.2, 45, 9, 44], 'Cost': 11.2}
# Iteration no: 298
# {'Time, Speed, Fuel, Distance': [1.2, 45, 9, 44], 'Cost': 11.2}
# Iteration no: 299
# {'Time, Speed, Fuel, Distance': [1.2, 45, 9, 44], 'Cost': 11.2}
# Iteration no: 300
# {'Time, Speed, Fuel, Distance': [1.2, 45, 9, 44], 'Cost': 11.2}
# Iteration no: 301
# {'Time, Speed, Fuel, Distance': [1.2, 45, 9, 44], 'Cost': 11.2}
# Iteration no: 302
# {'Time, Speed, Fuel, Distance': [1.2, 45, 9, 44], 'Cost': 11.2}
# Iteration no: 303
# {'Time, Speed, Fuel, Distance': [1.2, 45, 9, 44], 'Cost': 11.2}
# Iteration no: 304
# {'Time, Speed, Fuel, Distance': [1.2, 45, 9, 44], 'Cost': 11.2}
# Iteration no: 305
# {'Time, Speed, Fuel, Distance': [1.2, 45, 9, 44], 'Cost': 11.2}
# Iteration no: 306
# {'Time, Speed, Fuel, Distance': [1.2, 45, 9, 44], 'Cost': 11.2}
# Iteration no: 307
# {'Time, Speed, Fuel, Distance': [1.2, 45, 9, 44], 'Cost': 11.2}
# Iteration no: 308
# {'Time, Speed, Fuel, Distance': [1.2, 45, 9, 44], 'Cost': 11.2}
# Iteration no: 309
# {'Time, Speed, Fuel, Distance': [1.2, 45, 9, 44], 'Cost': 11.2}
# Iteration no: 310
# {'Time, Speed, Fuel, Distance': [1.2, 45, 9, 44], 'Cost': 11.2}
# Iteration no: 311
# {'Time, Speed, Fuel, Distance': [1.2, 45, 9, 44], 'Cost': 11.2}
# Iteration no: 312
# {'Time, Speed, Fuel, Distance': [1.2, 45, 9, 44], 'Cost': 11.2}
# Iteration no: 313
# {'Time, Speed, Fuel, Distance': [1.2, 45, 9, 44], 'Cost': 11.2}
# Iteration no: 314
# {'Time, Speed, Fuel, Distance': [1.2, 45, 9, 44], 'Cost': 11.2}
# Iteration no: 315
# {'Time, Speed, Fuel, Distance': [1.2, 45, 9, 44], 'Cost': 11.2}
# Iteration no: 316
# {'Time, Speed, Fuel, Distance': [1.2, 45, 9, 44], 'Cost': 11.2}
# Iteration no: 317
# {'Time, Speed, Fuel, Distance': [1.2, 45, 9, 44], 'Cost': 11.2}
# Iteration no: 318
# {'Time, Speed, Fuel, Distance': [1.2, 45, 9, 44], 'Cost': 11.2}
# Iteration no: 319
# {'Time, Speed, Fuel, Distance': [1.2, 45, 9, 44], 'Cost': 11.2}
# Iteration no: 320
# {'Time, Speed, Fuel, Distance': [1.2, 45, 9, 44], 'Cost': 11.2}
# Iteration no: 321
# {'Time, Speed, Fuel, Distance': [1.2, 45, 9, 44], 'Cost': 11.2}
# Iteration no: 322
# {'Time, Speed, Fuel, Distance': [1.2, 45, 9, 44], 'Cost': 11.2}
# Iteration no: 323
# {'Time, Speed, Fuel, Distance': [1.2, 45, 9, 44], 'Cost': 11.2}
# Iteration no: 324
# {'Time, Speed, Fuel, Distance': [1.2, 45, 9, 44], 'Cost': 11.2}
# Iteration no: 325
# {'Time, Speed, Fuel, Distance': [1.2, 45, 9, 44], 'Cost': 11.2}
# Iteration no: 326
# {'Time, Speed, Fuel, Distance': [1.2, 45, 9, 44], 'Cost': 11.2}
# Iteration no: 327
# {'Time, Speed, Fuel, Distance': [1.2, 45, 9, 44], 'Cost': 11.2}
# Iteration no: 328
# {'Time, Speed, Fuel, Distance': [1.2, 45, 9, 44], 'Cost': 11.2}
# Iteration no: 329
# {'Time, Speed, Fuel, Distance': [1.2, 45, 9, 44], 'Cost': 11.2}
# Iteration no: 330
# {'Time, Speed, Fuel, Distance': [1.2, 45, 9, 44], 'Cost': 11.2}
# Iteration no: 331
# {'Time, Speed, Fuel, Distance': [1.2, 45, 9, 44], 'Cost': 11.2}
# Iteration no: 332
# {'Time, Speed, Fuel, Distance': [1.2, 45, 9, 44], 'Cost': 11.2}
# Iteration no: 333
# {'Time, Speed, Fuel, Distance': [1.2, 45, 9, 44], 'Cost': 11.2}
# Iteration no: 334
# {'Time, Speed, Fuel, Distance': [1.2, 45, 9, 44], 'Cost': 11.2}
# Iteration no: 335
# {'Time, Speed, Fuel, Distance': [1.2, 45, 9, 44], 'Cost': 11.2}
# Iteration no: 336
# {'Time, Speed, Fuel, Distance': [1.2, 45, 9, 44], 'Cost': 11.2}
# Iteration no: 337
# {'Time, Speed, Fuel, Distance': [1.2, 45, 9, 44], 'Cost': 11.2}
# Iteration no: 338
# {'Time, Speed, Fuel, Distance': [1.2, 45, 9, 44], 'Cost': 11.2}
# Iteration no: 339
# {'Time, Speed, Fuel, Distance': [1.2, 45, 9, 44], 'Cost': 11.2}
# Iteration no: 340
# {'Time, Speed, Fuel, Distance': [1.2, 45, 9, 44], 'Cost': 11.2}
# Iteration no: 341
# {'Time, Speed, Fuel, Distance': [1.2, 45, 9, 44], 'Cost': 11.2}
# Iteration no: 342
# {'Time, Speed, Fuel, Distance': [1.2, 45, 9, 44], 'Cost': 11.2}
# Iteration no: 343
# {'Time, Speed, Fuel, Distance': [1.2, 45, 9, 44], 'Cost': 11.2}
# Iteration no: 344
# {'Time, Speed, Fuel, Distance': [1.2, 45, 9, 44], 'Cost': 11.2}
# Iteration no: 345
# {'Time, Speed, Fuel, Distance': [1.2, 45, 9, 44], 'Cost': 11.2}
# Iteration no: 346
# {'Time, Speed, Fuel, Distance': [1.2, 45, 9, 44], 'Cost': 11.2}
# Iteration no: 347
# {'Time, Speed, Fuel, Distance': [1.2, 45, 9, 44], 'Cost': 11.2}
# Iteration no: 348
# {'Time, Speed, Fuel, Distance': [1.2, 45, 9, 44], 'Cost': 11.2}
# Iteration no: 349
# {'Time, Speed, Fuel, Distance': [1.2, 45, 9, 44], 'Cost': 11.2}
# Iteration no: 350
# {'Time, Speed, Fuel, Distance': [1.2, 45, 9, 44], 'Cost': 11.2}
# Iteration no: 351
# {'Time, Speed, Fuel, Distance': [1.2, 45, 9, 44], 'Cost': 11.2}
# Iteration no: 352
# {'Time, Speed, Fuel, Distance': [1.2, 45, 9, 44], 'Cost': 11.2}
# Iteration no: 353
# {'Time, Speed, Fuel, Distance': [1.2, 45, 9, 44], 'Cost': 11.2}
# Iteration no: 354
# {'Time, Speed, Fuel, Distance': [1.2, 45, 9, 44], 'Cost': 11.2}
# Iteration no: 355
# {'Time, Speed, Fuel, Distance': [1.2, 45, 9, 44], 'Cost': 11.2}
# Iteration no: 356
# {'Time, Speed, Fuel, Distance': [1.2, 45, 9, 44], 'Cost': 11.2}
# Iteration no: 357
# {'Time, Speed, Fuel, Distance': [1.2, 45, 9, 44], 'Cost': 11.2}
# Iteration no: 358
# {'Time, Speed, Fuel, Distance': [1.2, 45, 9, 44], 'Cost': 11.2}
# Iteration no: 359
# {'Time, Speed, Fuel, Distance': [1.2, 45, 9, 44], 'Cost': 11.2}
# Iteration no: 360
# {'Time, Speed, Fuel, Distance': [1.2, 45, 9, 44], 'Cost': 11.2}
# Iteration no: 361
# {'Time, Speed, Fuel, Distance': [1.2, 45, 9, 44], 'Cost': 11.2}
# Iteration no: 362
# {'Time, Speed, Fuel, Distance': [1.2, 45, 9, 44], 'Cost': 11.2}
# Iteration no: 363
# {'Time, Speed, Fuel, Distance': [1.2, 45, 9, 44], 'Cost': 11.2}
# Iteration no: 364
# {'Time, Speed, Fuel, Distance': [1.2, 45, 9, 44], 'Cost': 11.2}
# Iteration no: 365
# {'Time, Speed, Fuel, Distance': [1.2, 45, 9, 44], 'Cost': 11.2}
# Iteration no: 366
# {'Time, Speed, Fuel, Distance': [1.2, 45, 9, 44], 'Cost': 11.2}
# Iteration no: 367
# {'Time, Speed, Fuel, Distance': [1.2, 45, 9, 44], 'Cost': 11.2}
# Iteration no: 368
# {'Time, Speed, Fuel, Distance': [1.2, 45, 9, 44], 'Cost': 11.2}
# Iteration no: 369
# {'Time, Speed, Fuel, Distance': [1.2, 45, 9, 44], 'Cost': 11.2}
# Iteration no: 370
# {'Time, Speed, Fuel, Distance': [1.2, 45, 9, 44], 'Cost': 11.2}
# Iteration no: 371
# {'Time, Speed, Fuel, Distance': [1.2, 45, 9, 44], 'Cost': 11.2}
# Iteration no: 372
# {'Time, Speed, Fuel, Distance': [1.2, 45, 9, 44], 'Cost': 11.2}
# Iteration no: 373
# {'Time, Speed, Fuel, Distance': [1.2, 45, 9, 44], 'Cost': 11.2}
# Iteration no: 374
# {'Time, Speed, Fuel, Distance': [1.2, 45, 9, 44], 'Cost': 11.2}
# Iteration no: 375
# {'Time, Speed, Fuel, Distance': [1.2, 45, 9, 44], 'Cost': 11.2}
# Iteration no: 376
# {'Time, Speed, Fuel, Distance': [1.2, 45, 9, 44], 'Cost': 11.2}
# Iteration no: 377
# {'Time, Speed, Fuel, Distance': [1.2, 45, 9, 44], 'Cost': 11.2}
# Iteration no: 378
# {'Time, Speed, Fuel, Distance': [1.2, 45, 9, 44], 'Cost': 11.2}
# Iteration no: 379
# {'Time, Speed, Fuel, Distance': [1.2, 45, 9, 44], 'Cost': 11.2}
# Iteration no: 380
# {'Time, Speed, Fuel, Distance': [1.2, 45, 9, 44], 'Cost': 11.2}
# Iteration no: 381
# {'Time, Speed, Fuel, Distance': [1.2, 45, 9, 44], 'Cost': 11.2}
# Iteration no: 382
# {'Time, Speed, Fuel, Distance': [1.2, 45, 9, 44], 'Cost': 11.2}
# Iteration no: 383
# {'Time, Speed, Fuel, Distance': [1.2, 45, 9, 44], 'Cost': 11.2}
# Iteration no: 384
# {'Time, Speed, Fuel, Distance': [1.2, 45, 9, 44], 'Cost': 11.2}
# Iteration no: 385
# {'Time, Speed, Fuel, Distance': [1.2, 45, 9, 44], 'Cost': 11.2}
# Iteration no: 386
# {'Time, Speed, Fuel, Distance': [1.2, 45, 9, 44], 'Cost': 11.2}
# Iteration no: 387
# {'Time, Speed, Fuel, Distance': [1.2, 45, 9, 44], 'Cost': 11.2}
# Iteration no: 388
# {'Time, Speed, Fuel, Distance': [1.2, 45, 9, 44], 'Cost': 11.2}
# Iteration no: 389
# {'Time, Speed, Fuel, Distance': [1.2, 45, 9, 44], 'Cost': 11.2}
# Iteration no: 390
# {'Time, Speed, Fuel, Distance': [1.2, 45, 9, 44], 'Cost': 11.2}
# Iteration no: 391
# {'Time, Speed, Fuel, Distance': [1.2, 45, 9, 44], 'Cost': 11.2}
# Iteration no: 392
# {'Time, Speed, Fuel, Distance': [1.2, 45, 9, 44], 'Cost': 11.2}
# Iteration no: 393
# {'Time, Speed, Fuel, Distance': [1.2, 45, 9, 44], 'Cost': 11.2}
# Iteration no: 394
# {'Time, Speed, Fuel, Distance': [1.2, 45, 9, 44], 'Cost': 11.2}
# Iteration no: 395
# {'Time, Speed, Fuel, Distance': [1.2, 45, 9, 44], 'Cost': 11.2}
# Iteration no: 396
# {'Time, Speed, Fuel, Distance': [1.2, 45, 9, 44], 'Cost': 11.2}
# Iteration no: 397
# {'Time, Speed, Fuel, Distance': [1.2, 45, 9, 44], 'Cost': 11.2}
# Iteration no: 398
# {'Time, Speed, Fuel, Distance': [1.2, 45, 9, 44], 'Cost': 11.2}
# Iteration no: 399
# {'Time, Speed, Fuel, Distance': [1.2, 45, 9, 44], 'Cost': 11.2}
# Iteration no: 400
# {'Time, Speed, Fuel, Distance': [1.2, 45, 9, 44], 'Cost': 11.2}
# Iteration no: 401
# {'Time, Speed, Fuel, Distance': [1.2, 45, 9, 44], 'Cost': 11.2}
# Iteration no: 402
# {'Time, Speed, Fuel, Distance': [1.2, 45, 9, 44], 'Cost': 11.2}
# Iteration no: 403
# {'Time, Speed, Fuel, Distance': [1.2, 45, 9, 44], 'Cost': 11.2}
# Iteration no: 404
# {'Time, Speed, Fuel, Distance': [1.2, 45, 9, 44], 'Cost': 11.2}
# Iteration no: 405
# {'Time, Speed, Fuel, Distance': [1.2, 45, 9, 44], 'Cost': 11.2}
# Iteration no: 406
# {'Time, Speed, Fuel, Distance': [1.2, 45, 9, 44], 'Cost': 11.2}
# Iteration no: 407
# {'Time, Speed, Fuel, Distance': [1.2, 45, 9, 44], 'Cost': 11.2}
# Iteration no: 408
# {'Time, Speed, Fuel, Distance': [1.2, 45, 9, 44], 'Cost': 11.2}
# Iteration no: 409
# {'Time, Speed, Fuel, Distance': [1.2, 45, 9, 44], 'Cost': 11.2}
# Iteration no: 410
# {'Time, Speed, Fuel, Distance': [1.2, 45, 9, 44], 'Cost': 11.2}
# Iteration no: 411
# {'Time, Speed, Fuel, Distance': [1.2, 45, 9, 44], 'Cost': 11.2}
# Iteration no: 412
# {'Time, Speed, Fuel, Distance': [1.2, 45, 9, 44], 'Cost': 11.2}
# Iteration no: 413
# {'Time, Speed, Fuel, Distance': [1.2, 45, 9, 44], 'Cost': 11.2}
# Iteration no: 414
# {'Time, Speed, Fuel, Distance': [1.2, 45, 9, 44], 'Cost': 11.2}
# Iteration no: 415
# {'Time, Speed, Fuel, Distance': [1.2, 45, 9, 44], 'Cost': 11.2}
# Iteration no: 416
# {'Time, Speed, Fuel, Distance': [1.2, 45, 9, 44], 'Cost': 11.2}
# Iteration no: 417
# {'Time, Speed, Fuel, Distance': [1.2, 45, 9, 44], 'Cost': 11.2}
# Iteration no: 418
# {'Time, Speed, Fuel, Distance': [1.2, 45, 9, 44], 'Cost': 11.2}
# Iteration no: 419
# {'Time, Speed, Fuel, Distance': [1.2, 45, 9, 44], 'Cost': 11.2}
# Iteration no: 420
# {'Time, Speed, Fuel, Distance': [1.2, 45, 9, 44], 'Cost': 11.2}
# Iteration no: 421
# {'Time, Speed, Fuel, Distance': [1.2, 45, 9, 44], 'Cost': 11.2}
# Iteration no: 422
# {'Time, Speed, Fuel, Distance': [1.2, 45, 9, 44], 'Cost': 11.2}
# Iteration no: 423
# {'Time, Speed, Fuel, Distance': [1.2, 45, 9, 44], 'Cost': 11.2}
# Iteration no: 424
# {'Time, Speed, Fuel, Distance': [1.2, 45, 9, 44], 'Cost': 11.2}
# Iteration no: 425
# {'Time, Speed, Fuel, Distance': [1.2, 45, 9, 44], 'Cost': 11.2}
# Iteration no: 426
# {'Time, Speed, Fuel, Distance': [1.2, 45, 9, 44], 'Cost': 11.2}
# Iteration no: 427
# {'Time, Speed, Fuel, Distance': [1.2, 45, 9, 44], 'Cost': 11.2}
# Iteration no: 428
# {'Time, Speed, Fuel, Distance': [1.2, 45, 9, 44], 'Cost': 11.2}
# Iteration no: 429
# {'Time, Speed, Fuel, Distance': [1.2, 45, 9, 44], 'Cost': 11.2}
# Iteration no: 430
# {'Time, Speed, Fuel, Distance': [1.2, 45, 9, 44], 'Cost': 11.2}
# Iteration no: 431
# {'Time, Speed, Fuel, Distance': [1.2, 45, 9, 44], 'Cost': 11.2}
# Iteration no: 432
# {'Time, Speed, Fuel, Distance': [1.2, 45, 9, 44], 'Cost': 11.2}
# Iteration no: 433
# {'Time, Speed, Fuel, Distance': [1.2, 45, 9, 44], 'Cost': 11.2}
# Iteration no: 434
# {'Time, Speed, Fuel, Distance': [1.2, 45, 9, 44], 'Cost': 11.2}
# Iteration no: 435
# {'Time, Speed, Fuel, Distance': [1.2, 45, 9, 44], 'Cost': 11.2}
# Iteration no: 436
# {'Time, Speed, Fuel, Distance': [1.2, 45, 9, 44], 'Cost': 11.2}
# Iteration no: 437
# {'Time, Speed, Fuel, Distance': [1.2, 45, 9, 44], 'Cost': 11.2}
# Iteration no: 438
# {'Time, Speed, Fuel, Distance': [1.2, 45, 9, 44], 'Cost': 11.2}
# Iteration no: 439
# {'Time, Speed, Fuel, Distance': [1.2, 45, 9, 44], 'Cost': 11.2}
# Iteration no: 440
# {'Time, Speed, Fuel, Distance': [1.2, 45, 9, 44], 'Cost': 11.2}
# Iteration no: 441
# {'Time, Speed, Fuel, Distance': [1.2, 45, 9, 44], 'Cost': 11.2}
# Iteration no: 442
# {'Time, Speed, Fuel, Distance': [1.2, 45, 9, 44], 'Cost': 11.2}
# Iteration no: 443
# {'Time, Speed, Fuel, Distance': [1.2, 45, 9, 44], 'Cost': 11.2}
# Iteration no: 444
# {'Time, Speed, Fuel, Distance': [1.2, 45, 9, 44], 'Cost': 11.2}
# Iteration no: 445
# {'Time, Speed, Fuel, Distance': [1.2, 45, 9, 44], 'Cost': 11.2}
# Iteration no: 446
# {'Time, Speed, Fuel, Distance': [1.2, 45, 9, 44], 'Cost': 11.2}
# Iteration no: 447
# {'Time, Speed, Fuel, Distance': [1.2, 45, 9, 44], 'Cost': 11.2}
# Iteration no: 448
# {'Time, Speed, Fuel, Distance': [1.2, 45, 9, 44], 'Cost': 11.2}
# Iteration no: 449
# {'Time, Speed, Fuel, Distance': [1.2, 45, 9, 44], 'Cost': 11.2}
# Iteration no: 450
# {'Time, Speed, Fuel, Distance': [1.2, 45, 9, 44], 'Cost': 11.2}
# Iteration no: 451
# {'Time, Speed, Fuel, Distance': [1.2, 45, 9, 44], 'Cost': 11.2}
# Iteration no: 452
# {'Time, Speed, Fuel, Distance': [1.2, 45, 9, 44], 'Cost': 11.2}
# Iteration no: 453
# {'Time, Speed, Fuel, Distance': [1.2, 45, 9, 44], 'Cost': 11.2}
# Iteration no: 454
# {'Time, Speed, Fuel, Distance': [1.2, 45, 9, 44], 'Cost': 11.2}
# Iteration no: 455
# {'Time, Speed, Fuel, Distance': [1.2, 45, 9, 44], 'Cost': 11.2}
# Iteration no: 456
# {'Time, Speed, Fuel, Distance': [1.2, 45, 9, 44], 'Cost': 11.2}
# Iteration no: 457
# {'Time, Speed, Fuel, Distance': [1.2, 45, 9, 44], 'Cost': 11.2}
# Iteration no: 458
# {'Time, Speed, Fuel, Distance': [1.2, 45, 9, 44], 'Cost': 11.2}
# Iteration no: 459
# {'Time, Speed, Fuel, Distance': [1.2, 45, 9, 44], 'Cost': 11.2}
# Iteration no: 460
# {'Time, Speed, Fuel, Distance': [1.2, 45, 9, 44], 'Cost': 11.2}
# Iteration no: 461
# {'Time, Speed, Fuel, Distance': [1.2, 45, 9, 44], 'Cost': 11.2}
# Iteration no: 462
# {'Time, Speed, Fuel, Distance': [1.2, 45, 9, 44], 'Cost': 11.2}
# Iteration no: 463
# {'Time, Speed, Fuel, Distance': [1.2, 45, 9, 44], 'Cost': 11.2}
# Iteration no: 464
# {'Time, Speed, Fuel, Distance': [1.2, 45, 9, 44], 'Cost': 11.2}
# Iteration no: 465
# {'Time, Speed, Fuel, Distance': [1.2, 45, 9, 44], 'Cost': 11.2}
# Iteration no: 466
# {'Time, Speed, Fuel, Distance': [1.2, 45, 9, 44], 'Cost': 11.2}
# Iteration no: 467
# {'Time, Speed, Fuel, Distance': [1.2, 45, 9, 44], 'Cost': 11.2}
# Iteration no: 468
# {'Time, Speed, Fuel, Distance': [1.2, 45, 9, 44], 'Cost': 11.2}
# Iteration no: 469
# {'Time, Speed, Fuel, Distance': [1.2, 45, 9, 44], 'Cost': 11.2}
# Iteration no: 470
# {'Time, Speed, Fuel, Distance': [1.2, 45, 9, 44], 'Cost': 11.2}
# Iteration no: 471
# {'Time, Speed, Fuel, Distance': [1.2, 45, 9, 44], 'Cost': 11.2}
# Iteration no: 472
# {'Time, Speed, Fuel, Distance': [1.2, 45, 9, 44], 'Cost': 11.2}
# Iteration no: 473
# {'Time, Speed, Fuel, Distance': [1.2, 45, 9, 44], 'Cost': 11.2}
# Iteration no: 474
# {'Time, Speed, Fuel, Distance': [1.2, 45, 9, 44], 'Cost': 11.2}
# Iteration no: 475
# {'Time, Speed, Fuel, Distance': [1.2, 45, 9, 44], 'Cost': 11.2}
# Iteration no: 476
# {'Time, Speed, Fuel, Distance': [1.2, 45, 9, 44], 'Cost': 11.2}
# Iteration no: 477
# {'Time, Speed, Fuel, Distance': [1.2, 45, 9, 44], 'Cost': 11.2}
# Iteration no: 478
# {'Time, Speed, Fuel, Distance': [1.2, 45, 9, 44], 'Cost': 11.2}
# Iteration no: 479
# {'Time, Speed, Fuel, Distance': [1.2, 45, 9, 44], 'Cost': 11.2}
# Iteration no: 480
# {'Time, Speed, Fuel, Distance': [1.2, 45, 9, 44], 'Cost': 11.2}
# Iteration no: 481
# {'Time, Speed, Fuel, Distance': [1.2, 45, 9, 44], 'Cost': 11.2}
# Iteration no: 482
# {'Time, Speed, Fuel, Distance': [1.2, 45, 9, 44], 'Cost': 11.2}
# Iteration no: 483
# {'Time, Speed, Fuel, Distance': [1.2, 45, 9, 44], 'Cost': 11.2}
# Iteration no: 484
# {'Time, Speed, Fuel, Distance': [1.2, 45, 9, 44], 'Cost': 11.2}
# Iteration no: 485
# {'Time, Speed, Fuel, Distance': [1.2, 45, 9, 44], 'Cost': 11.2}
# Iteration no: 486
# {'Time, Speed, Fuel, Distance': [1.2, 45, 9, 44], 'Cost': 11.2}
# Iteration no: 487
# {'Time, Speed, Fuel, Distance': [1.2, 45, 9, 44], 'Cost': 11.2}
# Iteration no: 488
# {'Time, Speed, Fuel, Distance': [1.2, 45, 9, 44], 'Cost': 11.2}
# Iteration no: 489
# {'Time, Speed, Fuel, Distance': [1.2, 45, 9, 44], 'Cost': 11.2}
# Iteration no: 490
# {'Time, Speed, Fuel, Distance': [1.2, 45, 9, 44], 'Cost': 11.2}
# Iteration no: 491
# {'Time, Speed, Fuel, Distance': [1.2, 45, 9, 44], 'Cost': 11.2}
# Iteration no: 492
# {'Time, Speed, Fuel, Distance': [1.2, 45, 9, 44], 'Cost': 11.2}
# Iteration no: 493
# {'Time, Speed, Fuel, Distance': [1.2, 45, 9, 44], 'Cost': 11.2}
# Iteration no: 494
# {'Time, Speed, Fuel, Distance': [1.2, 45, 9, 44], 'Cost': 11.2}
# Iteration no: 495
# {'Time, Speed, Fuel, Distance': [1.2, 45, 9, 44], 'Cost': 11.2}
# Iteration no: 496
# {'Time, Speed, Fuel, Distance': [1.2, 45, 9, 44], 'Cost': 11.2}
# Iteration no: 497
# {'Time, Speed, Fuel, Distance': [1.2, 45, 9, 44], 'Cost': 11.2}
# Iteration no: 498
# {'Time, Speed, Fuel, Distance': [1.2, 45, 9, 44], 'Cost': 11.2}
# Iteration no: 499
# {'Time, Speed, Fuel, Distance': [1.2, 45, 9, 44], 'Cost': 11.2}
# Iteration no: 500
# {'Time, Speed, Fuel, Distance': [1.2, 45, 9, 44], 'Cost': 11.2}
# Iteration no: 501
# {'Time, Speed, Fuel, Distance': [1.2, 45, 9, 44], 'Cost': 11.2}
# Iteration no: 502
# {'Time, Speed, Fuel, Distance': [1.2, 45, 9, 44], 'Cost': 11.2}
# Iteration no: 503
# {'Time, Speed, Fuel, Distance': [1.2, 45, 9, 44], 'Cost': 11.2}
# Iteration no: 504
# {'Time, Speed, Fuel, Distance': [1.2, 45, 9, 44], 'Cost': 11.2}
# Iteration no: 505
# {'Time, Speed, Fuel, Distance': [1.2, 45, 9, 44], 'Cost': 11.2}
# Iteration no: 506
# {'Time, Speed, Fuel, Distance': [1.2, 45, 9, 44], 'Cost': 11.2}
# Iteration no: 507
# {'Time, Speed, Fuel, Distance': [1.2, 45, 9, 44], 'Cost': 11.2}
# Iteration no: 508
# {'Time, Speed, Fuel, Distance': [1.2, 45, 9, 44], 'Cost': 11.2}
# Iteration no: 509
# {'Time, Speed, Fuel, Distance': [1.2, 45, 9, 44], 'Cost': 11.2}
# Iteration no: 510
# {'Time, Speed, Fuel, Distance': [1.2, 45, 9, 44], 'Cost': 11.2}
# Iteration no: 511
# {'Time, Speed, Fuel, Distance': [1.2, 45, 9, 44], 'Cost': 11.2}
# Iteration no: 512
# {'Time, Speed, Fuel, Distance': [1.2, 45, 9, 44], 'Cost': 11.2}
# Iteration no: 513
# {'Time, Speed, Fuel, Distance': [1.2, 45, 9, 44], 'Cost': 11.2}
# Iteration no: 514
# {'Time, Speed, Fuel, Distance': [1.2, 45, 9, 44], 'Cost': 11.2}
# Iteration no: 515
# {'Time, Speed, Fuel, Distance': [1.2, 45, 9, 44], 'Cost': 11.2}
# Iteration no: 516
# {'Time, Speed, Fuel, Distance': [1.2, 45, 9, 44], 'Cost': 11.2}
# Iteration no: 517
# {'Time, Speed, Fuel, Distance': [1.2, 45, 9, 44], 'Cost': 11.2}
# Iteration no: 518
# {'Time, Speed, Fuel, Distance': [1.2, 45, 9, 44], 'Cost': 11.2}
# Iteration no: 519
# {'Time, Speed, Fuel, Distance': [1.2, 45, 9, 44], 'Cost': 11.2}
# Iteration no: 520
# {'Time, Speed, Fuel, Distance': [1.2, 45, 9, 44], 'Cost': 11.2}
# Iteration no: 521
# {'Time, Speed, Fuel, Distance': [1.2, 45, 9, 44], 'Cost': 11.2}
# Iteration no: 522
# {'Time, Speed, Fuel, Distance': [1.2, 45, 9, 44], 'Cost': 11.2}
# Iteration no: 523
# {'Time, Speed, Fuel, Distance': [1.2, 45, 9, 44], 'Cost': 11.2}
# Iteration no: 524
# {'Time, Speed, Fuel, Distance': [1.2, 45, 9, 44], 'Cost': 11.2}
# Iteration no: 525
# {'Time, Speed, Fuel, Distance': [1.2, 45, 9, 44], 'Cost': 11.2}
# Iteration no: 526
# {'Time, Speed, Fuel, Distance': [1.2, 45, 9, 44], 'Cost': 11.2}
# Iteration no: 527
# {'Time, Speed, Fuel, Distance': [1.2, 45, 9, 44], 'Cost': 11.2}
# Iteration no: 528
# {'Time, Speed, Fuel, Distance': [1.2, 45, 9, 44], 'Cost': 11.2}
# Iteration no: 529
# {'Time, Speed, Fuel, Distance': [1.2, 45, 9, 44], 'Cost': 11.2}
# Iteration no: 530
# {'Time, Speed, Fuel, Distance': [1.2, 45, 9, 44], 'Cost': 11.2}
# Iteration no: 531
# {'Time, Speed, Fuel, Distance': [1.2, 45, 9, 44], 'Cost': 11.2}
# Iteration no: 532
# {'Time, Speed, Fuel, Distance': [1.2, 45, 9, 44], 'Cost': 11.2}
# Iteration no: 533
# {'Time, Speed, Fuel, Distance': [1.2, 45, 9, 44], 'Cost': 11.2}
# Iteration no: 534
# {'Time, Speed, Fuel, Distance': [1.2, 45, 9, 44], 'Cost': 11.2}
# Iteration no: 535
# {'Time, Speed, Fuel, Distance': [1.2, 45, 9, 44], 'Cost': 11.2}
# Iteration no: 536
# {'Time, Speed, Fuel, Distance': [1.2, 45, 9, 44], 'Cost': 11.2}
# Iteration no: 537
# {'Time, Speed, Fuel, Distance': [1.2, 45, 9, 44], 'Cost': 11.2}
# Iteration no: 538
# {'Time, Speed, Fuel, Distance': [1.2, 45, 9, 44], 'Cost': 11.2}
# Iteration no: 539
# {'Time, Speed, Fuel, Distance': [1.2, 45, 9, 44], 'Cost': 11.2}
# Iteration no: 540
# {'Time, Speed, Fuel, Distance': [1.2, 45, 9, 44], 'Cost': 11.2}
# Iteration no: 541
# {'Time, Speed, Fuel, Distance': [1.2, 45, 9, 44], 'Cost': 11.2}
# Iteration no: 542
# {'Time, Speed, Fuel, Distance': [1.2, 45, 9, 44], 'Cost': 11.2}
# Iteration no: 543
# {'Time, Speed, Fuel, Distance': [1.2, 45, 9, 44], 'Cost': 11.2}
# Iteration no: 544
# {'Time, Speed, Fuel, Distance': [1.2, 45, 9, 44], 'Cost': 11.2}
# Iteration no: 545
# {'Time, Speed, Fuel, Distance': [1.2, 45, 9, 44], 'Cost': 11.2}
# Iteration no: 546
# {'Time, Speed, Fuel, Distance': [1.2, 45, 9, 44], 'Cost': 11.2}
# Iteration no: 547
# {'Time, Speed, Fuel, Distance': [1.2, 45, 9, 44], 'Cost': 11.2}
# Iteration no: 548
# {'Time, Speed, Fuel, Distance': [1.2, 45, 9, 44], 'Cost': 11.2}
# Iteration no: 549
# {'Time, Speed, Fuel, Distance': [1.2, 45, 9, 44], 'Cost': 11.2}
# Iteration no: 550
# {'Time, Speed, Fuel, Distance': [1.2, 45, 9, 44], 'Cost': 11.2}
# Iteration no: 551
# {'Time, Speed, Fuel, Distance': [1.2, 45, 9, 44], 'Cost': 11.2}
# Iteration no: 552
# {'Time, Speed, Fuel, Distance': [1.2, 45, 9, 44], 'Cost': 11.2}
# Iteration no: 553
# {'Time, Speed, Fuel, Distance': [1.2, 45, 9, 44], 'Cost': 11.2}
# Iteration no: 554
# {'Time, Speed, Fuel, Distance': [1.2, 45, 9, 44], 'Cost': 11.2}
# Iteration no: 555
# {'Time, Speed, Fuel, Distance': [1.2, 45, 9, 44], 'Cost': 11.2}
# Iteration no: 556
# {'Time, Speed, Fuel, Distance': [1.2, 45, 9, 44], 'Cost': 11.2}
# Iteration no: 557
# {'Time, Speed, Fuel, Distance': [1.2, 45, 9, 44], 'Cost': 11.2}
# Iteration no: 558
# {'Time, Speed, Fuel, Distance': [1.2, 45, 9, 44], 'Cost': 11.2}
# Iteration no: 559
# {'Time, Speed, Fuel, Distance': [1.2, 45, 9, 44], 'Cost': 11.2}
# Iteration no: 560
# {'Time, Speed, Fuel, Distance': [1.2, 45, 9, 44], 'Cost': 11.2}
# Iteration no: 561
# {'Time, Speed, Fuel, Distance': [1.2, 45, 9, 44], 'Cost': 11.2}
# Iteration no: 562
# {'Time, Speed, Fuel, Distance': [1.2, 45, 9, 44], 'Cost': 11.2}
# Iteration no: 563
# {'Time, Speed, Fuel, Distance': [1.2, 45, 9, 44], 'Cost': 11.2}
# Iteration no: 564
# {'Time, Speed, Fuel, Distance': [1.2, 45, 9, 44], 'Cost': 11.2}
# Iteration no: 565
# {'Time, Speed, Fuel, Distance': [1.2, 45, 9, 44], 'Cost': 11.2}
# Iteration no: 566
# {'Time, Speed, Fuel, Distance': [1.2, 45, 9, 44], 'Cost': 11.2}
# Iteration no: 567
# {'Time, Speed, Fuel, Distance': [1.2, 45, 9, 44], 'Cost': 11.2}
# Iteration no: 568
# {'Time, Speed, Fuel, Distance': [1.2, 45, 9, 44], 'Cost': 11.2}
# Iteration no: 569
# {'Time, Speed, Fuel, Distance': [1.2, 45, 9, 44], 'Cost': 11.2}
# Iteration no: 570
# {'Time, Speed, Fuel, Distance': [1.2, 45, 9, 44], 'Cost': 11.2}
# Iteration no: 571
# {'Time, Speed, Fuel, Distance': [1.2, 45, 9, 44], 'Cost': 11.2}
# Iteration no: 572
# {'Time, Speed, Fuel, Distance': [1.2, 45, 9, 44], 'Cost': 11.2}
# Iteration no: 573
# {'Time, Speed, Fuel, Distance': [1.2, 45, 9, 44], 'Cost': 11.2}
# Iteration no: 574
# {'Time, Speed, Fuel, Distance': [1.2, 45, 9, 44], 'Cost': 11.2}
# Iteration no: 575
# {'Time, Speed, Fuel, Distance': [1.2, 45, 9, 44], 'Cost': 11.2}
# Iteration no: 576
# {'Time, Speed, Fuel, Distance': [1.2, 45, 9, 44], 'Cost': 11.2}
# Iteration no: 577
# {'Time, Speed, Fuel, Distance': [1.2, 45, 9, 44], 'Cost': 11.2}
# Iteration no: 578
# {'Time, Speed, Fuel, Distance': [1.2, 45, 9, 44], 'Cost': 11.2}
# Iteration no: 579
# {'Time, Speed, Fuel, Distance': [1.2, 45, 9, 44], 'Cost': 11.2}
# Iteration no: 580
# {'Time, Speed, Fuel, Distance': [1.2, 45, 9, 44], 'Cost': 11.2}
# Iteration no: 581
# ...
# Iteration no: 9810
# {'Time, Speed, Fuel, Distance': [1.58, 50, 3, 54], 'Cost': 0.58}
# Iteration no: 9811
# {'Time, Speed, Fuel, Distance': [1.58, 50, 3, 54], 'Cost': 0.58}
# Iteration no: 9812
# {'Time, Speed, Fuel, Distance': [1.58, 50, 3, 54], 'Cost': 0.58}
# Iteration no: 9813
# {'Time, Speed, Fuel, Distance': [1.58, 50, 3, 54], 'Cost': 0.58}
# Iteration no: 9814
# {'Time, Speed, Fuel, Distance': [1.58, 50, 3, 54], 'Cost': 0.58}
# Iteration no: 9815
# {'Time, Speed, Fuel, Distance': [1.58, 50, 3, 54], 'Cost': 0.58}
# Iteration no: 9816
# {'Time, Speed, Fuel, Distance': [1.58, 50, 3, 54], 'Cost': 0.58}
# Iteration no: 9817
# {'Time, Speed, Fuel, Distance': [1.58, 50, 3, 54], 'Cost': 0.58}
# Iteration no: 9818
# {'Time, Speed, Fuel, Distance': [1.58, 50, 3, 54], 'Cost': 0.58}
# Iteration no: 9819
# {'Time, Speed, Fuel, Distance': [1.58, 50, 3, 54], 'Cost': 0.58}
# Iteration no: 9820
# {'Time, Speed, Fuel, Distance': [1.58, 50, 3, 54], 'Cost': 0.58}
# Iteration no: 9821
# {'Time, Speed, Fuel, Distance': [1.58, 50, 3, 54], 'Cost': 0.58}
# Iteration no: 9822
# {'Time, Speed, Fuel, Distance': [1.58, 50, 3, 54], 'Cost': 0.58}
# Iteration no: 9823
# {'Time, Speed, Fuel, Distance': [1.58, 50, 3, 54], 'Cost': 0.58}
# Iteration no: 9824
# {'Time, Speed, Fuel, Distance': [1.58, 50, 3, 54], 'Cost': 0.58}
# Iteration no: 9825
# {'Time, Speed, Fuel, Distance': [1.58, 50, 3, 54], 'Cost': 0.58}
# Iteration no: 9826
# {'Time, Speed, Fuel, Distance': [1.58, 50, 3, 54], 'Cost': 0.58}
# Iteration no: 9827
# {'Time, Speed, Fuel, Distance': [1.58, 50, 3, 54], 'Cost': 0.58}
# Iteration no: 9828
# {'Time, Speed, Fuel, Distance': [1.58, 50, 3, 54], 'Cost': 0.58}
# Iteration no: 9829
# {'Time, Speed, Fuel, Distance': [1.58, 50, 3, 54], 'Cost': 0.58}
# Iteration no: 9830
# {'Time, Speed, Fuel, Distance': [1.58, 50, 3, 54], 'Cost': 0.58}
# Iteration no: 9831
# {'Time, Speed, Fuel, Distance': [1.58, 50, 3, 54], 'Cost': 0.58}
# Iteration no: 9832
# {'Time, Speed, Fuel, Distance': [1.58, 50, 3, 54], 'Cost': 0.58}
# Iteration no: 9833
# {'Time, Speed, Fuel, Distance': [1.58, 50, 3, 54], 'Cost': 0.58}
# Iteration no: 9834
# {'Time, Speed, Fuel, Distance': [1.58, 50, 3, 54], 'Cost': 0.58}
# Iteration no: 9835
# {'Time, Speed, Fuel, Distance': [1.58, 50, 3, 54], 'Cost': 0.58}
# Iteration no: 9836
# {'Time, Speed, Fuel, Distance': [1.58, 50, 3, 54], 'Cost': 0.58}
# Iteration no: 9837
# {'Time, Speed, Fuel, Distance': [1.58, 50, 3, 54], 'Cost': 0.58}
# Iteration no: 9838
# {'Time, Speed, Fuel, Distance': [1.58, 50, 3, 54], 'Cost': 0.58}
# Iteration no: 9839
# {'Time, Speed, Fuel, Distance': [1.58, 50, 3, 54], 'Cost': 0.58}
# Iteration no: 9840
# {'Time, Speed, Fuel, Distance': [1.58, 50, 3, 54], 'Cost': 0.58}
# Iteration no: 9841
# {'Time, Speed, Fuel, Distance': [1.58, 50, 3, 54], 'Cost': 0.58}
# Iteration no: 9842
# {'Time, Speed, Fuel, Distance': [1.58, 50, 3, 54], 'Cost': 0.58}
# Iteration no: 9843
# {'Time, Speed, Fuel, Distance': [1.58, 50, 3, 54], 'Cost': 0.58}
# Iteration no: 9844
# {'Time, Speed, Fuel, Distance': [1.58, 50, 3, 54], 'Cost': 0.58}
# Iteration no: 9845
# {'Time, Speed, Fuel, Distance': [1.58, 50, 3, 54], 'Cost': 0.58}
# Iteration no: 9846
# {'Time, Speed, Fuel, Distance': [1.58, 50, 3, 54], 'Cost': 0.58}
# Iteration no: 9847
# {'Time, Speed, Fuel, Distance': [1.58, 50, 3, 54], 'Cost': 0.58}
# Iteration no: 9848
# {'Time, Speed, Fuel, Distance': [1.58, 50, 3, 54], 'Cost': 0.58}
# Iteration no: 9849
# {'Time, Speed, Fuel, Distance': [1.58, 50, 3, 54], 'Cost': 0.58}
# Iteration no: 9850
# {'Time, Speed, Fuel, Distance': [1.58, 50, 3, 54], 'Cost': 0.58}
# Iteration no: 9851
# {'Time, Speed, Fuel, Distance': [1.58, 50, 3, 54], 'Cost': 0.58}
# Iteration no: 9852
# {'Time, Speed, Fuel, Distance': [1.58, 50, 3, 54], 'Cost': 0.58}
# Iteration no: 9853
# {'Time, Speed, Fuel, Distance': [1.58, 50, 3, 54], 'Cost': 0.58}
# Iteration no: 9854
# {'Time, Speed, Fuel, Distance': [1.58, 50, 3, 54], 'Cost': 0.58}
# Iteration no: 9855
# {'Time, Speed, Fuel, Distance': [1.58, 50, 3, 54], 'Cost': 0.58}
# Iteration no: 9856
# {'Time, Speed, Fuel, Distance': [1.58, 50, 3, 54], 'Cost': 0.58}
# Iteration no: 9857
# {'Time, Speed, Fuel, Distance': [1.58, 50, 3, 54], 'Cost': 0.58}
# Iteration no: 9858
# {'Time, Speed, Fuel, Distance': [1.58, 50, 3, 54], 'Cost': 0.58}
# Iteration no: 9859
# {'Time, Speed, Fuel, Distance': [1.58, 50, 3, 54], 'Cost': 0.58}
# Iteration no: 9860
# {'Time, Speed, Fuel, Distance': [1.58, 50, 3, 54], 'Cost': 0.58}
# Iteration no: 9861
# {'Time, Speed, Fuel, Distance': [1.58, 50, 3, 54], 'Cost': 0.58}
# Iteration no: 9862
# {'Time, Speed, Fuel, Distance': [1.58, 50, 3, 54], 'Cost': 0.58}
# Iteration no: 9863
# {'Time, Speed, Fuel, Distance': [1.58, 50, 3, 54], 'Cost': 0.58}
# Iteration no: 9864
# {'Time, Speed, Fuel, Distance': [1.58, 50, 3, 54], 'Cost': 0.58}
# Iteration no: 9865
# {'Time, Speed, Fuel, Distance': [1.58, 50, 3, 54], 'Cost': 0.58}
# Iteration no: 9866
# {'Time, Speed, Fuel, Distance': [1.58, 50, 3, 54], 'Cost': 0.58}
# Iteration no: 9867
# {'Time, Speed, Fuel, Distance': [1.58, 50, 3, 54], 'Cost': 0.58}
# Iteration no: 9868
# {'Time, Speed, Fuel, Distance': [1.58, 50, 3, 54], 'Cost': 0.58}
# Iteration no: 9869
# {'Time, Speed, Fuel, Distance': [1.58, 50, 3, 54], 'Cost': 0.58}
# Iteration no: 9870
# {'Time, Speed, Fuel, Distance': [1.58, 50, 3, 54], 'Cost': 0.58}
# Iteration no: 9871
# {'Time, Speed, Fuel, Distance': [1.58, 50, 3, 54], 'Cost': 0.58}
# Iteration no: 9872
# {'Time, Speed, Fuel, Distance': [1.58, 50, 3, 54], 'Cost': 0.58}
# Iteration no: 9873
# {'Time, Speed, Fuel, Distance': [1.58, 50, 3, 54], 'Cost': 0.58}
# Iteration no: 9874
# {'Time, Speed, Fuel, Distance': [1.58, 50, 3, 54], 'Cost': 0.58}
# Iteration no: 9875
# {'Time, Speed, Fuel, Distance': [1.58, 50, 3, 54], 'Cost': 0.58}
# Iteration no: 9876
# {'Time, Speed, Fuel, Distance': [1.58, 50, 3, 54], 'Cost': 0.58}
# Iteration no: 9877
# {'Time, Speed, Fuel, Distance': [1.58, 50, 3, 54], 'Cost': 0.58}
# Iteration no: 9878
# {'Time, Speed, Fuel, Distance': [1.58, 50, 3, 54], 'Cost': 0.58}
# Iteration no: 9879
# {'Time, Speed, Fuel, Distance': [1.58, 50, 3, 54], 'Cost': 0.58}
# Iteration no: 9880
# {'Time, Speed, Fuel, Distance': [1.58, 50, 3, 54], 'Cost': 0.58}
# Iteration no: 9881
# {'Time, Speed, Fuel, Distance': [1.58, 50, 3, 54], 'Cost': 0.58}
# Iteration no: 9882
# {'Time, Speed, Fuel, Distance': [1.58, 50, 3, 54], 'Cost': 0.58}
# Iteration no: 9883
# {'Time, Speed, Fuel, Distance': [1.58, 50, 3, 54], 'Cost': 0.58}
# Iteration no: 9884
# {'Time, Speed, Fuel, Distance': [1.58, 50, 3, 54], 'Cost': 0.58}
# Iteration no: 9885
# {'Time, Speed, Fuel, Distance': [1.58, 50, 3, 54], 'Cost': 0.58}
# Iteration no: 9886
# {'Time, Speed, Fuel, Distance': [1.58, 50, 3, 54], 'Cost': 0.58}
# Iteration no: 9887
# {'Time, Speed, Fuel, Distance': [1.58, 50, 3, 54], 'Cost': 0.58}
# Iteration no: 9888
# {'Time, Speed, Fuel, Distance': [1.58, 50, 3, 54], 'Cost': 0.58}
# Iteration no: 9889
# {'Time, Speed, Fuel, Distance': [1.58, 50, 3, 54], 'Cost': 0.58}
# Iteration no: 9890
# {'Time, Speed, Fuel, Distance': [1.58, 50, 3, 54], 'Cost': 0.58}
# Iteration no: 9891
# {'Time, Speed, Fuel, Distance': [1.58, 50, 3, 54], 'Cost': 0.58}
# Iteration no: 9892
# {'Time, Speed, Fuel, Distance': [1.58, 50, 3, 54], 'Cost': 0.58}
# Iteration no: 9893
# {'Time, Speed, Fuel, Distance': [1.58, 50, 3, 54], 'Cost': 0.58}
# Iteration no: 9894
# {'Time, Speed, Fuel, Distance': [1.58, 50, 3, 54], 'Cost': 0.58}
# Iteration no: 9895
# {'Time, Speed, Fuel, Distance': [1.58, 50, 3, 54], 'Cost': 0.58}
# Iteration no: 9896
# {'Time, Speed, Fuel, Distance': [1.58, 50, 3, 54], 'Cost': 0.58}
# Iteration no: 9897
# {'Time, Speed, Fuel, Distance': [1.58, 50, 3, 54], 'Cost': 0.58}
# Iteration no: 9898
# {'Time, Speed, Fuel, Distance': [1.58, 50, 3, 54], 'Cost': 0.58}
# Iteration no: 9899
# {'Time, Speed, Fuel, Distance': [1.58, 50, 3, 54], 'Cost': 0.58}
# Iteration no: 9900
# {'Time, Speed, Fuel, Distance': [1.58, 50, 3, 54], 'Cost': 0.58}
# Iteration no: 9901
# {'Time, Speed, Fuel, Distance': [1.58, 50, 3, 54], 'Cost': 0.58}
# Iteration no: 9902
# {'Time, Speed, Fuel, Distance': [1.58, 50, 3, 54], 'Cost': 0.58}
# Iteration no: 9903
# {'Time, Speed, Fuel, Distance': [1.58, 50, 3, 54], 'Cost': 0.58}
# Iteration no: 9904
# {'Time, Speed, Fuel, Distance': [1.58, 50, 3, 54], 'Cost': 0.58}
# Iteration no: 9905
# {'Time, Speed, Fuel, Distance': [1.58, 50, 3, 54], 'Cost': 0.58}
# Iteration no: 9906
# {'Time, Speed, Fuel, Distance': [1.58, 50, 3, 54], 'Cost': 0.58}
# Iteration no: 9907
# {'Time, Speed, Fuel, Distance': [1.58, 50, 3, 54], 'Cost': 0.58}
# Iteration no: 9908
# {'Time, Speed, Fuel, Distance': [1.58, 50, 3, 54], 'Cost': 0.58}
# Iteration no: 9909
# {'Time, Speed, Fuel, Distance': [1.58, 50, 3, 54], 'Cost': 0.58}
# Iteration no: 9910
# {'Time, Speed, Fuel, Distance': [1.58, 50, 3, 54], 'Cost': 0.58}
# Iteration no: 9911
# {'Time, Speed, Fuel, Distance': [1.58, 50, 3, 54], 'Cost': 0.58}
# Iteration no: 9912
# {'Time, Speed, Fuel, Distance': [1.58, 50, 3, 54], 'Cost': 0.58}
# Iteration no: 9913
# {'Time, Speed, Fuel, Distance': [1.58, 50, 3, 54], 'Cost': 0.58}
# Iteration no: 9914
# {'Time, Speed, Fuel, Distance': [1.58, 50, 3, 54], 'Cost': 0.58}
# Iteration no: 9915
# {'Time, Speed, Fuel, Distance': [1.58, 50, 3, 54], 'Cost': 0.58}
# Iteration no: 9916
# {'Time, Speed, Fuel, Distance': [1.58, 50, 3, 54], 'Cost': 0.58}
# Iteration no: 9917
# {'Time, Speed, Fuel, Distance': [1.58, 50, 3, 54], 'Cost': 0.58}
# Iteration no: 9918
# {'Time, Speed, Fuel, Distance': [1.58, 50, 3, 54], 'Cost': 0.58}
# Iteration no: 9919
# {'Time, Speed, Fuel, Distance': [1.58, 50, 3, 54], 'Cost': 0.58}
# Iteration no: 9920
# {'Time, Speed, Fuel, Distance': [1.58, 50, 3, 54], 'Cost': 0.58}
# Iteration no: 9921
# {'Time, Speed, Fuel, Distance': [1.58, 50, 3, 54], 'Cost': 0.58}
# Iteration no: 9922
# {'Time, Speed, Fuel, Distance': [1.58, 50, 3, 54], 'Cost': 0.58}
# Iteration no: 9923
# {'Time, Speed, Fuel, Distance': [1.58, 50, 3, 54], 'Cost': 0.58}
# Iteration no: 9924
# {'Time, Speed, Fuel, Distance': [1.58, 50, 3, 54], 'Cost': 0.58}
# Iteration no: 9925
# {'Time, Speed, Fuel, Distance': [1.58, 50, 3, 54], 'Cost': 0.58}
# Iteration no: 9926
# {'Time, Speed, Fuel, Distance': [1.58, 50, 3, 54], 'Cost': 0.58}
# Iteration no: 9927
# {'Time, Speed, Fuel, Distance': [1.58, 50, 3, 54], 'Cost': 0.58}
# Iteration no: 9928
# {'Time, Speed, Fuel, Distance': [1.58, 50, 3, 54], 'Cost': 0.58}
# Iteration no: 9929
# {'Time, Speed, Fuel, Distance': [1.58, 50, 3, 54], 'Cost': 0.58}
# Iteration no: 9930
# {'Time, Speed, Fuel, Distance': [1.58, 50, 3, 54], 'Cost': 0.58}
# Iteration no: 9931
# {'Time, Speed, Fuel, Distance': [1.58, 50, 3, 54], 'Cost': 0.58}
# Iteration no: 9932
# {'Time, Speed, Fuel, Distance': [1.58, 50, 3, 54], 'Cost': 0.58}
# Iteration no: 9933
# {'Time, Speed, Fuel, Distance': [1.58, 50, 3, 54], 'Cost': 0.58}
# Iteration no: 9934
# {'Time, Speed, Fuel, Distance': [1.58, 50, 3, 54], 'Cost': 0.58}
# Iteration no: 9935
# {'Time, Speed, Fuel, Distance': [1.58, 50, 3, 54], 'Cost': 0.58}
# Iteration no: 9936
# {'Time, Speed, Fuel, Distance': [1.58, 50, 3, 54], 'Cost': 0.58}
# Iteration no: 9937
# {'Time, Speed, Fuel, Distance': [1.58, 50, 3, 54], 'Cost': 0.58}
# Iteration no: 9938
# {'Time, Speed, Fuel, Distance': [1.58, 50, 3, 54], 'Cost': 0.58}
# Iteration no: 9939
# {'Time, Speed, Fuel, Distance': [1.58, 50, 3, 54], 'Cost': 0.58}
# Iteration no: 9940
# {'Time, Speed, Fuel, Distance': [1.58, 50, 3, 54], 'Cost': 0.58}
# Iteration no: 9941
# {'Time, Speed, Fuel, Distance': [1.58, 50, 3, 54], 'Cost': 0.58}
# Iteration no: 9942
# {'Time, Speed, Fuel, Distance': [1.58, 50, 3, 54], 'Cost': 0.58}
# Iteration no: 9943
# {'Time, Speed, Fuel, Distance': [1.58, 50, 3, 54], 'Cost': 0.58}
# Iteration no: 9944
# {'Time, Speed, Fuel, Distance': [1.58, 50, 3, 54], 'Cost': 0.58}
# Iteration no: 9945
# {'Time, Speed, Fuel, Distance': [1.58, 50, 3, 54], 'Cost': 0.58}
# Iteration no: 9946
# {'Time, Speed, Fuel, Distance': [1.58, 50, 3, 54], 'Cost': 0.58}
# Iteration no: 9947
# {'Time, Speed, Fuel, Distance': [1.58, 50, 3, 54], 'Cost': 0.58}
# Iteration no: 9948
# {'Time, Speed, Fuel, Distance': [1.58, 50, 3, 54], 'Cost': 0.58}
# Iteration no: 9949
# {'Time, Speed, Fuel, Distance': [1.58, 50, 3, 54], 'Cost': 0.58}
# Iteration no: 9950
# {'Time, Speed, Fuel, Distance': [1.58, 50, 3, 54], 'Cost': 0.58}
# Iteration no: 9951
# {'Time, Speed, Fuel, Distance': [1.58, 50, 3, 54], 'Cost': 0.58}
# Iteration no: 9952
# {'Time, Speed, Fuel, Distance': [1.58, 50, 3, 54], 'Cost': 0.58}
# Iteration no: 9953
# {'Time, Speed, Fuel, Distance': [1.58, 50, 3, 54], 'Cost': 0.58}
# Iteration no: 9954
# {'Time, Speed, Fuel, Distance': [1.58, 50, 3, 54], 'Cost': 0.58}
# Iteration no: 9955
# {'Time, Speed, Fuel, Distance': [1.58, 50, 3, 54], 'Cost': 0.58}
# Iteration no: 9956
# {'Time, Speed, Fuel, Distance': [1.58, 50, 3, 54], 'Cost': 0.58}
# Iteration no: 9957
# {'Time, Speed, Fuel, Distance': [1.58, 50, 3, 54], 'Cost': 0.58}
# Iteration no: 9958
# {'Time, Speed, Fuel, Distance': [1.58, 50, 3, 54], 'Cost': 0.58}
# Iteration no: 9959
# {'Time, Speed, Fuel, Distance': [1.58, 50, 3, 54], 'Cost': 0.58}
# Iteration no: 9960
# {'Time, Speed, Fuel, Distance': [1.58, 50, 3, 54], 'Cost': 0.58}
# Iteration no: 9961
# {'Time, Speed, Fuel, Distance': [1.58, 50, 3, 54], 'Cost': 0.58}
# Iteration no: 9962
# {'Time, Speed, Fuel, Distance': [1.58, 50, 3, 54], 'Cost': 0.58}
# Iteration no: 9963
# {'Time, Speed, Fuel, Distance': [1.58, 50, 3, 54], 'Cost': 0.58}
# Iteration no: 9964
# {'Time, Speed, Fuel, Distance': [1.58, 50, 3, 54], 'Cost': 0.58}
# Iteration no: 9965
# {'Time, Speed, Fuel, Distance': [1.58, 50, 3, 54], 'Cost': 0.58}
# Iteration no: 9966
# {'Time, Speed, Fuel, Distance': [1.58, 50, 3, 54], 'Cost': 0.58}
# Iteration no: 9967
# {'Time, Speed, Fuel, Distance': [1.58, 50, 3, 54], 'Cost': 0.58}
# Iteration no: 9968
# {'Time, Speed, Fuel, Distance': [1.58, 50, 3, 54], 'Cost': 0.58}
# Iteration no: 9969
# {'Time, Speed, Fuel, Distance': [1.58, 50, 3, 54], 'Cost': 0.58}
# Iteration no: 9970
# {'Time, Speed, Fuel, Distance': [1.58, 50, 3, 54], 'Cost': 0.58}
# Iteration no: 9971
# {'Time, Speed, Fuel, Distance': [1.58, 50, 3, 54], 'Cost': 0.58}
# Iteration no: 9972
# {'Time, Speed, Fuel, Distance': [1.58, 50, 3, 54], 'Cost': 0.58}
# Iteration no: 9973
# {'Time, Speed, Fuel, Distance': [1.58, 50, 3, 54], 'Cost': 0.58}
# Iteration no: 9974
# {'Time, Speed, Fuel, Distance': [1.58, 50, 3, 54], 'Cost': 0.58}
# Iteration no: 9975
# {'Time, Speed, Fuel, Distance': [1.58, 50, 3, 54], 'Cost': 0.58}
# Iteration no: 9976
# {'Time, Speed, Fuel, Distance': [1.58, 50, 3, 54], 'Cost': 0.58}
# Iteration no: 9977
# {'Time, Speed, Fuel, Distance': [1.58, 50, 3, 54], 'Cost': 0.58}
# Iteration no: 9978
# {'Time, Speed, Fuel, Distance': [1.58, 50, 3, 54], 'Cost': 0.58}
# Iteration no: 9979
# {'Time, Speed, Fuel, Distance': [1.58, 50, 3, 54], 'Cost': 0.58}
# Iteration no: 9980
# {'Time, Speed, Fuel, Distance': [1.58, 50, 3, 54], 'Cost': 0.58}
# Iteration no: 9981
# {'Time, Speed, Fuel, Distance': [1.58, 50, 3, 54], 'Cost': 0.58}
# Iteration no: 9982
# {'Time, Speed, Fuel, Distance': [1.58, 50, 3, 54], 'Cost': 0.58}
# Iteration no: 9983
# {'Time, Speed, Fuel, Distance': [1.58, 50, 3, 54], 'Cost': 0.58}
# Iteration no: 9984
# {'Time, Speed, Fuel, Distance': [1.58, 50, 3, 54], 'Cost': 0.58}
# Iteration no: 9985
# {'Time, Speed, Fuel, Distance': [1.58, 50, 3, 54], 'Cost': 0.58}
# Iteration no: 9986
# {'Time, Speed, Fuel, Distance': [1.58, 50, 3, 54], 'Cost': 0.58}
# Iteration no: 9987
# {'Time, Speed, Fuel, Distance': [1.58, 50, 3, 54], 'Cost': 0.58}
# Iteration no: 9988
# {'Time, Speed, Fuel, Distance': [1.58, 50, 3, 54], 'Cost': 0.58}
# Iteration no: 9989
# {'Time, Speed, Fuel, Distance': [1.58, 50, 3, 54], 'Cost': 0.58}
# Iteration no: 9990
# {'Time, Speed, Fuel, Distance': [1.58, 50, 3, 54], 'Cost': 0.58}
# Iteration no: 9991
# {'Time, Speed, Fuel, Distance': [1.58, 50, 3, 54], 'Cost': 0.58}
# Iteration no: 9992
# {'Time, Speed, Fuel, Distance': [1.58, 50, 3, 54], 'Cost': 0.58}
# Iteration no: 9993
# {'Time, Speed, Fuel, Distance': [1.58, 50, 3, 54], 'Cost': 0.58}
# Iteration no: 9994
# {'Time, Speed, Fuel, Distance': [1.58, 50, 3, 54], 'Cost': 0.58}
# Iteration no: 9995
# {'Time, Speed, Fuel, Distance': [1.58, 50, 3, 54], 'Cost': 0.58}
# Iteration no: 9996
# {'Time, Speed, Fuel, Distance': [1.58, 50, 3, 54], 'Cost': 0.58}
# Iteration no: 9997
# {'Time, Speed, Fuel, Distance': [1.58, 50, 3, 54], 'Cost': 0.58}
# Iteration no: 9998
# {'Time, Speed, Fuel, Distance': [1.58, 50, 3, 54], 'Cost': 0.58}
# Iteration no: 9999
# Solution
# 1.58  Hrs  50  Km/Hr  3 Litres 54 Kms
# Cost0.58
